# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
from sklearn.linear_model import LinearRegression
from sklearn.impute import SimpleImputer
from sklearn.metrics import mean_squared_error,mean_absolute_error
from sklearn.feature_selection import SelectKBest, f_regression, RFE
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.linear_model import Ridge, Lasso
from sklearn.metrics import r2_score
import warnings
warnings.filterwarnings('ignore')
plt.style.use('seaborn-pastel')
pd.set_option('display.max_rows', 200)

# %% [markdown]
# ### Cleaning

# %%
#Import the data
data = pd.read_csv('datasets/train.csv')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150634 entries, 0 to 150633
# Data columns (total 78 columns):
#  #   Column                     Non-Null Count   Dtype
# ---  ------                     --------------   -----
#  0   id                         150634 non-null  int64
#  1   Tranc_YearMonth            150634 non-null  object
#  2   town                       150634 non-null  object
#  3   flat_type                  150634 non-null  object
#  4   block                      150634 non-null  object
#  5   street_name                150634 non-null  object
#  6   storey_range               150634 non-null  object
#  7   floor_area_sqm             150634 non-null  float64
#  8   flat_model                 150634 non-null  object
#  9   lease_commence_date        150634 non-null  int64
#  10  resale_price               150634 non-null  float64
#  11  Tranc_Year                 150634 non-null  int64
#  12  Tranc_Month                150634 non-null  int64
#  13  mid_storey                 150634 non-null  int64
#  14  lower                      150634 non-null  int64
#  15  upper                      150634 non-null  int64
#  16  mid                        150634 non-null  int64
#  17  full_flat_type             150634 non-null  object
#  18  address                    150634 non-null  object
#  19  floor_area_sqft            150634 non-null  float64
#  20  price_per_sqft             150634 non-null  float64
#  21  hdb_age                    150634 non-null  int64
#  22  max_floor_lvl              150634 non-null  int64
#  23  year_completed             150634 non-null  int64
#  24  residential                150634 non-null  object
#  25  commercial                 150634 non-null  object
#  26  market_hawker              150634 non-null  object
#  27  multistorey_carpark        150634 non-null  object
#  28  precinct_pavilion          150634 non-null  object
#  29  total_dwelling_units       150634 non-null  int64
#  30  1room_sold                 150634 non-null  int64
#  31  2room_sold                 150634 non-null  int64
#  32  3room_sold                 150634 non-null  int64
#  33  4room_sold                 150634 non-null  int64
#  34  5room_sold                 150634 non-null  int64
#  35  exec_sold                  150634 non-null  int64
#  36  multigen_sold              150634 non-null  int64
#  37  studio_apartment_sold      150634 non-null  int64
#  38  1room_rental               150634 non-null  int64
#  39  2room_rental               150634 non-null  int64
#  40  3room_rental               150634 non-null  int64
#  41  other_room_rental          150634 non-null  int64
#  42  postal                     150634 non-null  object
#  43  Latitude                   150634 non-null  float64
#  44  Longitude                  150634 non-null  float64
#  45  planning_area              150634 non-null  object
#  46  Mall_Nearest_Distance      149805 non-null  float64
#  47  Mall_Within_500m           57845 non-null   float64
#  48  Mall_Within_1km            125208 non-null  float64
#  49  Mall_Within_2km            148694 non-null  float64
#  50  Hawker_Nearest_Distance    150634 non-null  float64
#  51  Hawker_Within_500m         53244 non-null   float64
#  52  Hawker_Within_1km          89766 non-null   float64
#  53  Hawker_Within_2km          121432 non-null  float64
#  54  hawker_food_stalls         150634 non-null  int64
#  55  hawker_market_stalls       150634 non-null  int64
#  56  mrt_nearest_distance       150634 non-null  float64
#  57  mrt_name                   150634 non-null  object
#  58  bus_interchange            150634 non-null  int64
#  59  mrt_interchange            150634 non-null  int64
#  60  mrt_latitude               150634 non-null  float64
#  61  mrt_longitude              150634 non-null  float64
#  62  bus_stop_nearest_distance  150634 non-null  float64
#  63  bus_stop_name              150634 non-null  object
#  64  bus_stop_latitude          150634 non-null  float64
#  65  bus_stop_longitude         150634 non-null  float64
#  66  pri_sch_nearest_distance   150634 non-null  float64
#  67  pri_sch_name               150634 non-null  object
#  68  vacancy                    150634 non-null  int64
#  69  pri_sch_affiliation        150634 non-null  int64
#  70  pri_sch_latitude           150634 non-null  float64
#  71  pri_sch_longitude          150634 non-null  float64
#  72  sec_sch_nearest_dist       150634 non-null  float64
#  73  sec_sch_name               150634 non-null  object
#  74  cutoff_point               150634 non-null  int64
#  75  affiliation                150634 non-null  int64
#  76  sec_sch_latitude           150634 non-null  float64
#  77  sec_sch_longitude          150634 non-null  float64
# dtypes: float64(26), int64(32), object(20)
# memory usage: 89.6+ MB

# %%
#standardizing all column names to be in snake case
data.columns = data.columns.str.lower().str.replace(' ','_')

# %%
#dropping price_per_sqft since we cannot use this for our prediction
data.drop('price_per_sqft', axis = 1, inplace = True)

# %%
data.corr()['resale_price'].sort_values()
# Out:
# 3room_sold                  -0.410368
# hdb_age                     -0.350337
# sec_sch_latitude            -0.216303
# latitude                    -0.216153
# bus_stop_latitude           -0.215760
# mrt_latitude                -0.214939
# pri_sch_latitude            -0.214707
# 2room_sold                  -0.145287
# total_dwelling_units        -0.140725
# mrt_nearest_distance        -0.128222
# mall_nearest_distance       -0.087096
# 3room_rental                -0.079965
# 2room_rental                -0.077548
# 1room_sold                  -0.039434
# 1room_rental                -0.037993
# hawker_food_stalls          -0.033581
# tranc_year                  -0.019146
# vacancy                     -0.016140
# hawker_nearest_distance     -0.014537
# pri_sch_nearest_distance    -0.011004
# hawker_market_stalls        -0.009378
# tranc_month                 -0.006823
# affiliation                 -0.000466
# bus_interchange              0.002547
# other_room_rental            0.013049
# pri_sch_affiliation          0.030931
# bus_stop_nearest_distance    0.031940
# cutoff_point                 0.034572
# multigen_sold                0.037406
# studio_apartment_sold        0.040312
# hawker_within_500m           0.062637
# mrt_interchange              0.066413
# mall_within_1km              0.069929
# mall_within_500m             0.086955
# 4room_sold                   0.092600
# sec_sch_nearest_dist         0.095339
# bus_stop_longitude           0.106394
# mrt_longitude                0.106506
# longitude                    0.106596
# pri_sch_longitude            0.106681
# sec_sch_longitude            0.108911
# mall_within_2km              0.115703
# hawker_within_1km            0.134415
# hawker_within_2km            0.185607
# exec_sold                    0.337500
# lease_commence_date          0.350337
# lower                        0.352466
# mid                          0.353213
# mid_storey                   0.353213
# upper                        0.353552
# year_completed               0.353698
# 5room_sold                   0.359434
# max_floor_lvl                0.495650
# id                           0.521504
# floor_area_sqft              0.654120
# floor_area_sqm               0.654120
# resale_price                 1.000000
# Name: resale_price, dtype: float64

# %%
#any columns with only 1 unique value will not be helpful in a prediction model 
for x in data.columns:
    print(x, len(data[x].unique()))
# Out:
# id 150634
# tranc_yearmonth 110
# town 26
# flat_type 7
# block 2514
# street_name 553
# storey_range 25
# floor_area_sqm 169
# flat_model 20
# lease_commence_date 54
# resale_price 3295
# tranc_year 10
# tranc_month 12
# mid_storey 22
# lower 22
# upper 23
# mid 22
# full_flat_type 43
# address 9157
# floor_area_sqft 169
# hdb_age 54
# max_floor_lvl 41
# year_completed 59
# residential 1
# commercial 2
# market_hawker 2
# multistorey_carpark 2
# precinct_pavilion 2
# total_dwelling_units 320
# 1room_sold 2
# 2room_sold 99
# 3room_sold 255
# 4room_sold 200
# 5room_sold 133
# exec_sold 103
# multigen_sold 7
# studio_apartment_sold 61
# 1room_rental 11
# 2room_rental 48
# 3room_rental 15
# other_room_rental 3
# postal 17483
# latitude 9126
# longitude 9098
# planning_area 32
# mall_nearest_distance 8983
# mall_within_500m 7
# mall_within_1km 16
# mall_within_2km 42
# hawker_nearest_distance 9126
# hawker_within_500m 6
# hawker_within_1km 10
# hawker_within_2km 20
# hawker_food_stalls 52
# hawker_market_stalls 70
# mrt_nearest_distance 9126
# mrt_name 94
# bus_interchange 2
# mrt_interchange 2
# mrt_latitude 94
# mrt_longitude 94
# bus_stop_nearest_distance 9126
# bus_stop_name 1657
# bus_stop_latitude 2011
# bus_stop_longitude 2011
# pri_sch_nearest_distance 9126
# pri_sch_name 177
# vacancy 66
# pri_sch_affiliation 2
# pri_sch_latitude 177
# pri_sch_longitude 177
# sec_sch_nearest_dist 9126
# sec_sch_name 134
# cutoff_point 54
# affiliation 2
# sec_sch_latitude 134
# sec_sch_longitude 134

# %%
#Dropping residential column due to only 1 unique value and id value as it is only use for identification
data.drop(['residential', 'id'], axis = 1, inplace=True)

# %%
data.columns
# Out:
# Index(['tranc_yearmonth', 'town', 'flat_type', 'block', 'street_name',
#        'storey_range', 'floor_area_sqm', 'flat_model', 'lease_commence_date',
#        'resale_price', 'tranc_year', 'tranc_month', 'mid_storey', 'lower',
#        'upper', 'mid', 'full_flat_type', 'address', 'floor_area_sqft',
#        'hdb_age', 'max_floor_lvl', 'year_completed', 'commercial',
#        'market_hawker', 'multistorey_carpark', 'precinct_pavilion',
#        'total_dwelling_units', '1room_sold', '2room_sold', '3room_sold',
#        '4room_sold', '5room_sold', 'exec_sold', 'multigen_sold',
#        'studio_apartment_sold', '1room_rental', '2room_rental', '3room_rental',
#        'other_room_rental', 'postal', 'latitude', 'longitude', 'planning_area',
#        'mall_nearest_distance', 'mall_within_500m', 'mall_within_1km',
#        'mall_within_2km', 'hawker_nearest_distance', 'hawker_within_500m',
#        'hawker_within_1km', 'hawker_within_2km', 'hawker_food_stalls',
#        'hawker_market_stalls', 'mrt_nearest_distance', 'mrt_name',
#        'bus_interchange', 'mrt_interchange', 'mrt_latitude', 'mrt_longitude',
#        'bus_stop_nearest_distance', 'bus_stop_name', 'bus_stop_latitude',
#        'bus_stop_longitude', 'pri_sch_nearest_distance', 'pri_sch_name',
#        'vacancy', 'pri_sch_affiliation', 'pri_sch_latitude',
#        'pri_sch_longitude', 'sec_sch_nearest_dist', 'sec_sch_name',
#        'cutoff_point', 'affiliation', 'sec_sch_latitude', 'sec_sch_longitude'],
#       dtype='object')

# %%
data.isnull().sum().sort_values().tail(8)
# Out:
# max_floor_lvl                0
# mall_nearest_distance      829
# mall_within_2km           1940
# mall_within_1km          25426
# hawker_within_2km        29202
# hawker_within_1km        60868
# mall_within_500m         92789
# hawker_within_500m       97390
# dtype: int64

# %%
#Exploring Null Rows - looks like null value are 0 (i.e. no malls within stated distance)
data[data['mall_nearest_distance'].isnull()][['mall_nearest_distance', 'mall_within_500m', 'mall_within_1km', 'mall_within_2km']]
# Out:
#         mall_nearest_distance  mall_within_500m  mall_within_1km  \
# 75                        NaN               NaN              NaN
# 321                       NaN               NaN              NaN
# 478                       NaN               NaN              NaN
# 643                       NaN               NaN              NaN
# 691                       NaN               NaN              NaN
# ...                       ...               ...              ...
# 150296                    NaN               NaN              NaN
# 150388                    NaN               NaN              NaN
# 150394                    NaN               NaN              NaN
# 150479                    NaN               NaN              NaN
# 150625                    NaN               NaN              NaN
#
#         mall_within_2km
# 75                  NaN
# 321                 NaN
# 478                 NaN
# 643                 NaN
# 691                 NaN
# ...                 ...
# 150296              NaN
# 150388              NaN
# 150394              NaN
# 150479              NaN
# 150625              NaN
#
# [829 rows x 4 columns]

# %%
#filling null values with 0
col_with_null = data.columns[data.isnull().sum() != 0].to_list()
imputer=SimpleImputer(missing_values=np.NaN, strategy='constant', fill_value=0)
for x in col_with_null:
    data[x]=imputer.fit_transform(data[x].values.reshape(-1,1))

# %%
#Since machine learning can only take numeric inputs, we will have to convert useful categorical columns to numeric form 
data.select_dtypes(include='object').columns
# Out:
# Index(['tranc_yearmonth', 'town', 'flat_type', 'block', 'street_name',
#        'storey_range', 'flat_model', 'full_flat_type', 'address', 'commercial',
#        'market_hawker', 'multistorey_carpark', 'precinct_pavilion', 'postal',
#        'planning_area', 'mrt_name', 'bus_stop_name', 'pri_sch_name',
#        'sec_sch_name'],
#       dtype='object')

# %%
#Checking if tranc_yearmonth is consistent with 'tranc_year', 'tranc_month'
data[['tranc_yearmonth','tranc_year', 'tranc_month']]
# Out:
#        tranc_yearmonth  tranc_year  tranc_month
# 0              2016-05        2016            5
# 1              2012-07        2012            7
# 2              2013-07        2013            7
# 3              2012-04        2012            4
# 4              2017-12        2017           12
# ...                ...         ...          ...
# 150629         2020-09        2020            9
# 150630         2017-06        2017            6
# 150631         2020-12        2020           12
# 150632         2016-05        2016            5
# 150633         2018-06        2018            6
#
# [150634 rows x 3 columns]

# %%
#drop trancyear
data.drop('tranc_yearmonth', axis = 1, inplace=True)

# %%
#checking if storey_range column is consistent with 'mid_storey', 'lower', 'upper', 'mid'
data[['storey_range','mid_storey', 'lower', 'upper', 'mid']]
# Out:
#        storey_range  mid_storey  lower  upper  mid
# 0          10 TO 12          11     10     12   11
# 1          07 TO 09           8      7      9    8
# 2          13 TO 15          14     13     15   14
# 3          01 TO 05           3      1      5    3
# 4          01 TO 03           2      1      3    2
# ...             ...         ...    ...    ...  ...
# 150629     04 TO 06           5      4      6    5
# 150630     04 TO 06           5      4      6    5
# 150631     10 TO 12          11     10     12   11
# 150632     07 TO 09           8      7      9    8
# 150633     07 TO 09           8      7      9    8
#
# [150634 rows x 5 columns]

# %%
#Checking if mid_storey == mid columns
(data['mid_storey'] == data['mid']).value_counts()
# Out:
# True    150634
# dtype: int64

# %%
#drop mid_storey
data.drop('mid_storey', axis = 1, inplace=True)

# %%
#checking if town == planning_area 
data[['town', 'planning_area']]
# Out:
#                    town planning_area
# 0       KALLANG/WHAMPOA       Kallang
# 1                BISHAN        Bishan
# 2           BUKIT BATOK   Bukit Batok
# 3                BISHAN        Bishan
# 4                YISHUN        Yishun
# ...                 ...           ...
# 150629        WOODLANDS     Woodlands
# 150630      JURONG WEST   Jurong West
# 150631            BEDOK         Bedok
# 150632       QUEENSTOWN    Queenstown
# 150633           YISHUN        Yishun
#
# [150634 rows x 2 columns]

# %%
data['town'] = data['town'].str.lower()
data['planning_area'] = data['planning_area'].str.lower()

# %%
data[['town', 'planning_area']]
# Out:
#                    town planning_area
# 0       kallang/whampoa       kallang
# 1                bishan        bishan
# 2           bukit batok   bukit batok
# 3                bishan        bishan
# 4                yishun        yishun
# ...                 ...           ...
# 150629        woodlands     woodlands
# 150630      jurong west   jurong west
# 150631            bedok         bedok
# 150632       queenstown    queenstown
# 150633           yishun        yishun
#
# [150634 rows x 2 columns]

# %%
(data['town'] == data['planning_area']).value_counts()
# Out:
# True     144931
# False      5703
# dtype: int64

# %%
data[(data['town'] == data['planning_area']) == False][['town', 'planning_area']]
# Out:
#                    town planning_area
# 0       kallang/whampoa       kallang
# 32      kallang/whampoa        novena
# 35      kallang/whampoa       kallang
# 55      kallang/whampoa       kallang
# 88         central area        rochor
# ...                 ...           ...
# 150507  kallang/whampoa       kallang
# 150510  kallang/whampoa       kallang
# 150511  kallang/whampoa       kallang
# 150524     central area        outram
# 150573     central area        outram
#
# [5703 rows x 2 columns]

# %%
#Planning area is more precise than town so we will drop town since most values are repeated
data.drop('town', axis = 1, inplace=True)

# %%
#checking if flat_type and full_flat_type is consistent
(data['flat_type'] == data['full_flat_type']).value_counts()
# Out:
# False    150634
# dtype: int64

# %%
data[['flat_type', 'full_flat_type', 'flat_model']]
# Out:
#                flat_type                     full_flat_type        flat_model
# 0                 4 ROOM                     4 ROOM Model A           Model A
# 1                 5 ROOM                    5 ROOM Improved          Improved
# 2              EXECUTIVE                EXECUTIVE Apartment         Apartment
# 3                 4 ROOM                     4 ROOM Model A           Model A
# 4                 4 ROOM                  4 ROOM Simplified        Simplified
# ...                  ...                                ...               ...
# 150629         EXECUTIVE                EXECUTIVE Apartment         Apartment
# 150630            5 ROOM                    5 ROOM Improved          Improved
# 150631         EXECUTIVE                EXECUTIVE Apartment         Apartment
# 150632            3 ROOM                    3 ROOM Improved          Improved
# 150633  MULTI-GENERATION  MULTI-GENERATION Multi Generation  Multi Generation
#
# [150634 rows x 3 columns]

# %%
#drop full_flat_type 
data.drop('full_flat_type', axis = 1, inplace = True)

# %%
#checking remaining object dtype columns and the number of values
for x in data.select_dtypes(include='object').columns:
    print(x, len(data[x].unique()))
# Out:
# flat_type 7
# block 2514
# street_name 553
# storey_range 25
# flat_model 20
# address 9157
# commercial 2
# market_hawker 2
# multistorey_carpark 2
# precinct_pavilion 2
# postal 17483
# planning_area 32
# mrt_name 94
# bus_stop_name 1657
# pri_sch_name 177
# sec_sch_name 134

# %%
#dropping block, street_name, address, postal and bus_stop_name as there are too many unique values 
data.drop(['block', 'street_name', 'address', 'postal', 'bus_stop_name'], axis = 1, inplace = True)

# %%
#Checking remaining columns
data.columns
# Out:
# Index(['flat_type', 'storey_range', 'floor_area_sqm', 'flat_model',
#        'lease_commence_date', 'resale_price', 'tranc_year', 'tranc_month',
#        'lower', 'upper', 'mid', 'floor_area_sqft', 'hdb_age', 'max_floor_lvl',
#        'year_completed', 'commercial', 'market_hawker', 'multistorey_carpark',
#        'precinct_pavilion', 'total_dwelling_units', '1room_sold', '2room_sold',
#        '3room_sold', '4room_sold', '5room_sold', 'exec_sold', 'multigen_sold',
#        'studio_apartment_sold', '1room_rental', '2room_rental', '3room_rental',
#        'other_room_rental', 'latitude', 'longitude', 'planning_area',
#        'mall_nearest_distance', 'mall_within_500m', 'mall_within_1km',
#        'mall_within_2km', 'hawker_nearest_distance', 'hawker_within_500m',
#        'hawker_within_1km', 'hawker_within_2km', 'hawker_food_stalls',
#        'hawker_market_stalls', 'mrt_nearest_distance', 'mrt_name',
#        'bus_interchange', 'mrt_interchange', 'mrt_latitude', 'mrt_longitude',
#        'bus_stop_nearest_distance', 'bus_stop_latitude', 'bus_stop_longitude',
#        'pri_sch_nearest_distance', 'pri_sch_name', 'vacancy',
#        'pri_sch_affiliation', 'pri_sch_latitude', 'pri_sch_longitude',
#        'sec_sch_nearest_dist', 'sec_sch_name', 'cutoff_point', 'affiliation',
#        'sec_sch_latitude', 'sec_sch_longitude'],
#       dtype='object')

# %%
#dropping longitude and latitude columns
data.drop(['latitude', 'longitude', 'mrt_latitude', 'mrt_longitude', 'bus_stop_latitude', 'bus_stop_longitude', 'pri_sch_latitude', 'pri_sch_longitude', 'sec_sch_latitude', 'sec_sch_longitude'], axis = 1, inplace = True)

# %%
#droppping floor_area_sqft becauses we have floor_area_sqm
data.drop('floor_area_sqft', axis = 1, inplace = True)

# %%
#dropping lease_commence_date and year_completed because we have hdb_age
data.drop(['lease_commence_date','year_completed'], axis = 1, inplace = True)

# %%
data.columns
# Out:
# Index(['flat_type', 'storey_range', 'floor_area_sqm', 'flat_model',
#        'resale_price', 'tranc_year', 'tranc_month', 'lower', 'upper', 'mid',
#        'hdb_age', 'max_floor_lvl', 'commercial', 'market_hawker',
#        'multistorey_carpark', 'precinct_pavilion', 'total_dwelling_units',
#        '1room_sold', '2room_sold', '3room_sold', '4room_sold', '5room_sold',
#        'exec_sold', 'multigen_sold', 'studio_apartment_sold', '1room_rental',
#        '2room_rental', '3room_rental', 'other_room_rental', 'planning_area',
#        'mall_nearest_distance', 'mall_within_500m', 'mall_within_1km',
#        'mall_within_2km', 'hawker_nearest_distance', 'hawker_within_500m',
#        'hawker_within_1km', 'hawker_within_2km', 'hawker_food_stalls',
#        'hawker_market_stalls', 'mrt_nearest_distance', 'mrt_name',
#        'bus_interchange', 'mrt_interchange', 'bus_stop_nearest_distance',
#        'pri_sch_nearest_distance', 'pri_sch_name', 'vacancy',
#        'pri_sch_affiliation', 'sec_sch_nearest_dist', 'sec_sch_name',
#        'cutoff_point', 'affiliation'],
#       dtype='object')

# %%
data.select_dtypes(include='object').columns
# Out:
# Index(['flat_type', 'storey_range', 'flat_model', 'commercial',
#        'market_hawker', 'multistorey_carpark', 'precinct_pavilion',
#        'planning_area', 'mrt_name', 'pri_sch_name', 'sec_sch_name'],
#       dtype='object')

# %%
data.select_dtypes(include=('int64', 'float64')).columns
# Out:
# Index(['floor_area_sqm', 'resale_price', 'tranc_year', 'tranc_month', 'lower',
#        'upper', 'mid', 'hdb_age', 'max_floor_lvl', 'total_dwelling_units',
#        '1room_sold', '2room_sold', '3room_sold', '4room_sold', '5room_sold',
#        'exec_sold', 'multigen_sold', 'studio_apartment_sold', '1room_rental',
#        '2room_rental', '3room_rental', 'other_room_rental',
#        'mall_nearest_distance', 'mall_within_500m', 'mall_within_1km',
#        'mall_within_2km', 'hawker_nearest_distance', 'hawker_within_500m',
#        'hawker_within_1km', 'hawker_within_2km', 'hawker_food_stalls',
#        'hawker_market_stalls', 'mrt_nearest_distance', 'bus_interchange',
#        'mrt_interchange', 'bus_stop_nearest_distance',
#        'pri_sch_nearest_distance', 'vacancy', 'pri_sch_affiliation',
#        'sec_sch_nearest_dist', 'cutoff_point', 'affiliation'],
#       dtype='object')

# %% [markdown]
# ## cleaning stops here

# %% [markdown]
# -------------------

# %% [markdown]
# # EDA and Features Selection

# %%
#checking for number of unique values in each quantitative column
for x in data.select_dtypes(include=('int64', 'float64')).columns:
    print(x, len(data[x].unique()))
# Out:
# floor_area_sqm 169
# resale_price 3295
# tranc_year 10
# tranc_month 12
# lower 22
# upper 23
# mid 22
# hdb_age 54
# max_floor_lvl 41
# total_dwelling_units 320
# 1room_sold 2
# 2room_sold 99
# 3room_sold 255
# 4room_sold 200
# 5room_sold 133
# exec_sold 103
# multigen_sold 7
# studio_apartment_sold 61
# 1room_rental 11
# 2room_rental 48
# 3room_rental 15
# other_room_rental 3
# mall_nearest_distance 8982
# mall_within_500m 7
# mall_within_1km 16
# mall_within_2km 42
# hawker_nearest_distance 9126
# hawker_within_500m 6
# hawker_within_1km 10
# hawker_within_2km 20
# hawker_food_stalls 52
# hawker_market_stalls 70
# mrt_nearest_distance 9126
# bus_interchange 2
# mrt_interchange 2
# bus_stop_nearest_distance 9126
# pri_sch_nearest_distance 9126
# vacancy 66
# pri_sch_affiliation 2
# sec_sch_nearest_dist 9126
# cutoff_point 54
# affiliation 2

# %%
data.corr()['resale_price']
# Out:
# floor_area_sqm               0.654120
# resale_price                 1.000000
# tranc_year                  -0.019146
# tranc_month                 -0.006823
# lower                        0.352466
# upper                        0.353552
# mid                          0.353213
# hdb_age                     -0.350337
# max_floor_lvl                0.495650
# total_dwelling_units        -0.140725
# 1room_sold                  -0.039434
# 2room_sold                  -0.145287
# 3room_sold                  -0.410368
# 4room_sold                   0.092600
# 5room_sold                   0.359434
# exec_sold                    0.337500
# multigen_sold                0.037406
# studio_apartment_sold        0.040312
# 1room_rental                -0.037993
# 2room_rental                -0.077548
# 3room_rental                -0.079965
# other_room_rental            0.013049
# mall_nearest_distance       -0.092239
# mall_within_500m             0.085151
# mall_within_1km              0.078815
# mall_within_2km              0.108648
# hawker_nearest_distance     -0.014537
# hawker_within_500m           0.012637
# hawker_within_1km            0.090516
# hawker_within_2km            0.183168
# hawker_food_stalls          -0.033581
# hawker_market_stalls        -0.009378
# mrt_nearest_distance        -0.128222
# bus_interchange              0.002547
# mrt_interchange              0.066413
# bus_stop_nearest_distance    0.031940
# pri_sch_nearest_distance    -0.011004
# vacancy                     -0.016140
# pri_sch_affiliation          0.030931
# sec_sch_nearest_dist         0.095339
# cutoff_point                 0.034572
# affiliation                 -0.000466
# Name: resale_price, dtype: float64

# %% [markdown]
# ### 1room_sold, mrt_interchange, pri_sch_affiliation, affiliation, bus_interchange

# %%
data['1room_sold'].unique()
# Out:
# array([  0, 255], dtype=int64)

# %%
#Checking for significant diffferences between flats in blocks with sold 1room flats vs those without
t_statistic, p_value = stats.ttest_ind(data[data['1room_sold'] == 255]['resale_price'], data[data['1room_sold'] == 0]['resale_price'])

print("t-statistic:", t_statistic)
print("p-value:", p_value)
# Out:
# t-statistic: -15.316865171784787
# p-value: 6.468195886612115e-53

# %%
data['mrt_interchange'].unique()
# Out:
# array([0, 1], dtype=int64)

# %%
#Checking for significant diffferences between flats with or without mrt station
t_statistic, p_value = stats.ttest_ind(data[data['mrt_interchange'] == 0]['resale_price'], data[data['mrt_interchange'] == 1]['resale_price'])

print("t-statistic:", t_statistic)
print("p-value:", p_value)
# Out:
# t-statistic: -25.832962030804353
# p-value: 7.919041573029868e-147

# %%
data['pri_sch_affiliation'].unique()
# Out:
# array([1, 0], dtype=int64)

# %%
#Checking for significant diffferences between flats with pri sch affliations vs those without
t_statistic, p_value = stats.ttest_ind(data[data['pri_sch_affiliation'] == 0]['resale_price'], data[data['pri_sch_affiliation'] == 1]['resale_price'])

print("t-statistic:", t_statistic)
print("p-value:", p_value)
# Out:
# t-statistic: -12.010394486100676
# p-value: 3.245046093756188e-33

# %%
#Checking for significant diffferences between flats with pri sch affliations vs those without
t_statistic, p_value = stats.ttest_ind(data[data['affiliation'] == 0]['resale_price'], data[data['affiliation'] == 1]['resale_price'])

print("t-statistic:", t_statistic)
print("p-value:", p_value)
# Out:
# t-statistic: 0.18098733357597738
# p-value: 0.8563777616694039

# %%
data.drop('affiliation', axis = 1, inplace = True)

# %%
data['bus_interchange'].unique()
# Out:
# array([0, 1], dtype=int64)

# %%
#Checking for significant diffferences between flats with or without bus stops
t_statistic, p_value = stats.ttest_ind(data[data['bus_interchange'] == 0]['resale_price'], data[data['bus_interchange'] == 1]['resale_price'])

print("t-statistic:", t_statistic)
print("p-value:", p_value)
# Out:
# t-statistic: -0.988570893024779
# p-value: 0.32287472097030323

# %%
data.drop('bus_interchange', axis = 1, inplace = True)

# %% [markdown]
# ### encoding

# %%
for x in data.select_dtypes(include='object').columns:
    print(x, len(data[x].unique()))
# Out:
# flat_type 7
# storey_range 25
# flat_model 20
# commercial 2
# market_hawker 2
# multistorey_carpark 2
# precinct_pavilion 2
# planning_area 32
# mrt_name 94
# pri_sch_name 177
# sec_sch_name 134

# %% [markdown]
# ### commercial, market_hawker, multistorey_carpark, precinct_pavilion

# %%
data['commercial'].unique()
# Out:
# array(['N', 'Y'], dtype=object)

# %%
#Checking for significant diffferences between flats with or without commercial units
t_statistic, p_value = stats.ttest_ind(data[data['commercial'] == 'N']['resale_price'], data[data['commercial'] == 'Y']['resale_price'])

print("t-statistic:", t_statistic)
print("p-value:", p_value)
# Out:
# t-statistic: 54.94959817005768
# p-value: 0.0

# %%
data['market_hawker'].unique()
# Out:
# array(['N', 'Y'], dtype=object)

# %%
#Checking for significant diffferences between flats with or without market_hawker
t_statistic, p_value = stats.ttest_ind(data[data['market_hawker'] == 'N']['resale_price'], data[data['market_hawker'] == 'Y']['resale_price'])

print("t-statistic:", t_statistic)
print("p-value:", p_value)
# Out:
# t-statistic: 2.3052979441153596
# p-value: 0.02115124474119538

# %%
data['multistorey_carpark'].unique()
# Out:
# array(['N', 'Y'], dtype=object)

# %%
#Checking for significant diffferences between flats with or without multistorey carpark
t_statistic, p_value = stats.ttest_ind(data[data['multistorey_carpark'] == 'N']['resale_price'], data[data['multistorey_carpark'] == 'Y']['resale_price'])

print("t-statistic:", t_statistic)
print("p-value:", p_value)
# Out:
# t-statistic: 3.0269930389667055
# p-value: 0.002470413669327056

# %%
#Checking for significant diffferences between flats with or without precinct pavilion
t_statistic, p_value = stats.ttest_ind(data[data['precinct_pavilion'] == 'N']['resale_price'], data[data['precinct_pavilion'] == 'Y']['resale_price'])

print("t-statistic:", t_statistic)
print("p-value:", p_value)
# Out:
# t-statistic: -0.2774293051005933
# p-value: 0.781450862895485

# %%
data.drop('precinct_pavilion', axis = 1, inplace = True)

# %%
data.columns
# Out:
# Index(['flat_type', 'storey_range', 'floor_area_sqm', 'flat_model',
#        'resale_price', 'tranc_year', 'tranc_month', 'lower', 'upper', 'mid',
#        'hdb_age', 'max_floor_lvl', 'commercial', 'market_hawker',
#        'multistorey_carpark', 'total_dwelling_units', '1room_sold',
#        '2room_sold', '3room_sold', '4room_sold', '5room_sold', 'exec_sold',
#        'multigen_sold', 'studio_apartment_sold', '1room_rental',
#        '2room_rental', '3room_rental', 'other_room_rental', 'planning_area',
#        'mall_nearest_distance', 'mall_within_500m', 'mall_within_1km',
#        'mall_within_2km', 'hawker_nearest_distance', 'hawker_within_500m',
#        'hawker_within_1km', 'hawker_within_2km', 'hawker_food_stalls',
#        'hawker_market_stalls', 'mrt_nearest_distance', 'mrt_name',
#        'mrt_interchange', 'bus_stop_nearest_distance',
#        'pri_sch_nearest_distance', 'pri_sch_name', 'vacancy',
#        'pri_sch_affiliation', 'sec_sch_nearest_dist', 'sec_sch_name',
#        'cutoff_point'],
#       dtype='object')

# %% [markdown]
# ### definition

# %%
def calculate_quantiles(x):
    return pd.Series([x.quantile(0.25), x.quantile(0.5), x.quantile(0.75), np.std(x)], index=['Q1', 'Q2', 'Q3', 'Std Dev'])

# %%
def replaceterm(data_col, listofvalues, newterm):
    return data[data_col].replace(listofvalues, newterm, inplace = True)

# %% [markdown]
# ### Storey Range

# %%
replaceterm('storey_range', ['01 TO 05', '01 TO 03', '04 TO 06'], 1)
replaceterm('storey_range', ['07 TO 09', '06 TO 10'], 2)
replaceterm('storey_range', ['10 TO 12', '13 TO 15', '11 TO 15'], 3)
replaceterm('storey_range', ['16 TO 18', '16 TO 20', '19 TO 21',], 4)
replaceterm('storey_range', ['21 TO 25', '22 TO 24'], 5)
replaceterm('storey_range', [ '25 TO 27', '26 TO 30', '28 TO 30'], 6)
replaceterm('storey_range', ['31 TO 33', '31 TO 35', '36 TO 40', '34 TO 36', '37 TO 39'], 7)
replaceterm('storey_range', ['43 TO 45', '40 TO 42', '49 TO 51', '46 TO 48'], 8)

# %% [markdown]
# ### flat_type

# %%
data.groupby('flat_type')['resale_price'].apply(calculate_quantiles).unstack()
# Out:
#                         Q1        Q2        Q3        Std Dev
# flat_type
# 1 ROOM            185000.0  209000.0  230000.0   25157.510690
# 2 ROOM            222000.0  245000.0  265000.0   35645.399904
# 3 ROOM            284000.0  318000.0  355000.0   68183.242489
# 4 ROOM            373000.0  420000.0  480000.0  109952.991210
# 5 ROOM            445000.0  500000.0  590000.0  134931.827799
# EXECUTIVE         560000.0  615000.0  690000.0  108538.078981
# MULTI-GENERATION  719500.0  765500.0  815750.0   77169.603401

# %%
flat_type_list = []
for x in data['flat_type'].unique():
    price = data[data['flat_type'] == x]['resale_price'].to_list()
    flat_type_list.append(price)
plt.boxplot(flat_type_list, vert=False)
locs, labels = plt.yticks()
plt.yticks(locs, data['flat_type'].unique())
plt.xlabel('Price (SGD$ million)')
plt.ylabel('Flat Type')
plt.vlines(360000, ymin = 0, ymax=7.5, linestyles='dashed')
plt.vlines(700000, ymin = 0, ymax=7.5, linestyles='dashed')
plt.title('Resale Price vs Flat Type')
# Out:
# Text(0.5, 1.0, 'Resale Price vs Flat Type')

# %%
low_flat_type = ['1 ROOM', '2 ROOM', '3 ROOM']
mid_flat_type = ['EXECUTIVE', '5 ROOM', '4 ROOM']
high_flat_type = ['MULTI-GENERATION']

# %%
replaceterm('flat_type', low_flat_type, 'low')
replaceterm('flat_type', mid_flat_type, 'mid')
replaceterm('flat_type', high_flat_type, 'high')

# %% [markdown]
# ### flat_model

# %%
flat_model_list = []
for x in data['flat_model'].unique():
    price = data[data['flat_model'] == x]['resale_price'].to_list()
    flat_model_list.append(price)
plt.boxplot(flat_model_list, vert=False)
locs, labels = plt.yticks()
plt.yticks(locs, data['flat_model'].unique())
plt.xlabel('Price (SGD$ million)')
plt.ylabel('Flat Model')
plt.vlines(540000, ymin = 0, ymax=20, linestyles='dashed')
plt.vlines(850000, ymin = 0, ymax=20, linestyles='dashed')
plt.title('Resale Price vs Flat Model')
# Out:
# Text(0.5, 1.0, 'Resale Price vs Flat Model')

# %%
#Doing ordinal encoding for flat_model
low_flat_model = ['2-room', 'Standard', 'Model A2', 'Premium Apartment', 'New Generation', 'Simplified', 'Improved', 'Model A']
high_flat_model = ['Type S2', 'Premium Apartment Loft', 'Type S1']
mid_flat_model = [x for x in data['flat_model'].unique().tolist() if x not in (low_flat_model + high_flat_model)]

# %%
replaceterm('flat_model', low_flat_model, 'low')
replaceterm('flat_model', mid_flat_model, 'mid')
replaceterm('flat_model', high_flat_model, 'high')

# %% [markdown]
# ### planning_area

# %%
data.groupby('planning_area')['resale_price'].apply(calculate_quantiles).unstack()
# Out:
#                                Q1        Q2        Q3        Std Dev
# planning_area
# ang mo kio               308000.0  365000.0  473000.0  149769.234387
# bedok                    310000.0  380000.0  492000.0  138513.224231
# bishan                   498000.0  595000.0  738000.0  173598.909610
# bukit batok              300000.0  368000.0  463000.0  124123.578664
# bukit merah              370000.0  568000.0  725000.0  199466.016881
# bukit panjang            354000.0  425000.0  498000.0  104823.940018
# bukit timah              555350.0  705500.0  873750.0  194277.747497
# changi                   280000.0  295000.0  305375.0   22291.357654
# choa chu kang            350000.0  401000.0  463000.0   84266.344422
# clementi                 335000.0  408000.0  560000.0  172249.184645
# downtown core            536500.0  650000.0  686500.0   88436.062869
# geylang                  290000.0  378000.0  555000.0  176244.652449
# hougang                  350000.0  418000.0  502500.0  127364.222565
# jurong east              320000.0  395000.0  510000.0  133980.780731
# jurong west              343000.0  410000.0  475888.0   98845.663125
# kallang                  350000.0  474800.0  645000.0  186395.130744
# marine parade            397000.0  470000.0  580000.0  172125.598064
# novena                   288000.0  400000.0  600000.0  185842.999219
# outram                   450000.0  680000.0  930000.0  266280.357673
# pasir ris                429000.0  483000.0  560000.0   96847.433008
# punggol                  420000.0  460000.0  519000.0   81911.031729
# queenstown               350000.0  520000.0  740000.0  218437.537448
# rochor                   385000.0  439500.0  508000.0  100058.511318
# sembawang                360000.0  405500.0  460000.0   70836.537398
# sengkang                 400000.0  449000.0  515000.0   81770.224350
# serangoon                371000.0  463888.0  585000.0  151272.341235
# tampines                 390000.0  456000.0  538000.0  116305.694662
# tanglin                  550000.0  828000.0  855000.0  169052.181293
# toa payoh                302000.0  392000.0  641888.0  211853.218621
# western water catchment  408250.0  430000.0  462000.0   47560.791508
# woodlands                338000.0  390000.0  445000.0   99735.799839
# yishun                   307000.0  357000.0  421000.0   95170.613338

# %%
planning_area_list = []
for x in data['planning_area'].unique():
    price = data[data['planning_area'] == x]['resale_price'].to_list()
    planning_area_list.append(price)
plt.figure(figsize=(8,10))
plt.boxplot(planning_area_list, vert=False)
locs, labels = plt.yticks()
plt.yticks(locs, data['planning_area'].unique())
plt.xlabel('Price (SGD$ million)')
plt.ylabel('Planning Area')
plt.title('Resale Price vs Planning Area')
# Out:
# Text(0.5, 1.0, 'Resale Price vs Planning Area')

# %%
data['planning_area'].unique()
# Out:
# array(['kallang', 'bishan', 'bukit batok', 'yishun', 'geylang', 'hougang',
#        'bedok', 'sengkang', 'tampines', 'serangoon', 'bukit merah',
#        'bukit panjang', 'woodlands', 'jurong west', 'toa payoh',
#        'choa chu kang', 'sembawang', 'novena', 'ang mo kio', 'pasir ris',
#        'clementi', 'punggol', 'jurong east', 'rochor', 'queenstown',
#        'bukit timah', 'outram', 'tanglin', 'marine parade',
#        'western water catchment', 'downtown core', 'changi'], dtype=object)

# %%
low_area = ['ang mo kio', 'bedok', 'bukit batok', 'bukit panjang', 'changi', 'choa chu kang', 'jurong west', 'sembawang', 'western water catchment', 'woodlands', 'yishun']
mid1_area = ['bukit merah', 'kallang', 'queenstown']
mid2_area = ['clementi', 'geylang', 'hougang', 'jurong east', 'marine parade', 'novena', 'pasir ris', 'punggol', 'rochor', 'sengkang', 'serangoon', 'tampines', 'toa payoh']
high_area = ['downtown core', 'tanglin', 'outram', 'bukit timah', 'bishan']

# %%
replaceterm('planning_area', low_area, 'low')
replaceterm('planning_area', mid1_area, 'mid1')
replaceterm('planning_area', mid2_area, 'mid2')
replaceterm('planning_area', high_area, 'high')

# %% [markdown]
# ### mrt_name

# %%
data.groupby('mrt_name')['resale_price'].apply(calculate_quantiles).unstack()
# Out:
#                        Q1        Q2        Q3        Std Dev
# mrt_name
# Admiralty        358000.0  400000.0  440000.0   70793.914395
# Aljunied         320000.0  376000.0  523500.0  151976.186933
# Ang Mo Kio       315000.0  378000.0  515000.0  158096.074579
# Bartley          411750.0  485000.0  585750.0  111296.162942
# Beauty World     675000.0  777500.0  915000.0  144623.957462
# Bedok            315000.0  370500.0  488000.0  145580.097298
# Bedok North      290000.0  330000.0  420200.0  119766.862486
# Bedok Reservoir  300000.0  358000.0  505000.0  126420.703676
# Bencoolen        440200.0  477500.0  538750.0   86566.514936
# Bendemeer        833000.0  840000.0  894000.0   51047.700914
# Bishan           510000.0  600000.0  767333.0  170299.000586
# Boon Keng        310000.0  425000.0  620000.0  204586.585264
# Boon Lay         376000.0  435000.0  497000.0  100691.358353
# Botanic Gardens  489444.0  540888.0  573500.0   68291.614854
# Braddell         285000.0  343000.0  460000.0  188023.775847
# Bras Basah       650000.0  655000.0  707000.0   42745.784371
# Buangkok         408000.0  452000.0  528000.0   92716.214720
# Bugis            480000.0  490000.0  504000.0   23556.079659
# Bukit Batok      297000.0  380000.0  490000.0  133022.137594
# Bukit Gombak     304000.0  360000.0  440000.0  105281.153248
# Bukit Panjang    353000.0  425000.0  498000.0  104213.447266
# Buona Vista      378000.0  480000.0  739722.0  205608.910859
# Caldecott        760000.0  828888.0  930000.0  136561.673933
# Canberra         290000.0  320000.0  373000.0   59858.325248
# Cashew           300000.0  350000.0  420000.0  105568.442064
# Changi Airport   280000.0  295000.0  305375.0   22291.357654
# Chinatown        313500.0  405000.0  479722.0  105895.214675
# Chinese Garden   315000.0  380000.0  478000.0  113393.796301
# Choa Chu Kang    348000.0  400000.0  451250.0   79506.672328
# Clarke Quay      440666.0  460000.0  475750.0   36888.795556
# Clementi         335000.0  403000.0  547500.0  169529.773673
# Commonwealth     292500.0  341000.0  669000.0  217370.847407
# Dakota           315000.0  349000.0  560000.0  225669.519997
# Dover            484500.0  650000.0  726250.0  161491.942881
# Eunos            390000.0  500000.0  648666.0  170458.532231
# Farrer Park      450000.0  520000.0  624166.0  111211.675610
# Farrer Road      400000.0  449000.0  828500.0  204667.086291
# Geylang Bahru    303500.0  346500.0  540000.0  152943.915399
# HarbourFront     332250.0  390000.0  500000.0  121953.031253
# Hillview         320000.0  342000.0  669000.0  186587.419022
# Holland Village  370000.0  455000.0  630000.0  183017.265375
# Hougang          343000.0  410000.0  495000.0  124167.652753
# Jalan Besar      375000.0  404000.0  516500.0  105365.068766
# Jurong East      325000.0  405000.0  526800.0  146843.328662
# Kaki Bukit       373000.0  431000.0  522500.0  118625.349523
# Kallang          475000.0  615000.0  700000.0  159811.125144
# Kembangan        385000.0  468000.0  700000.0  183725.694273
# Khatib           330000.0  388000.0  460000.0  107836.277707
# Kovan            340000.0  410000.0  535000.0  142462.084476
# Labrador Park    572500.0  645000.0  684000.0   66203.046137
# Lakeside         305000.0  370000.0  450000.0  108162.818847
# Lavender         354500.0  390000.0  676500.0  184049.638344
# Little India     435000.0  469500.0  518000.0   80665.252753
# Lorong Chuan     335000.0  480000.0  720000.0  193483.824083
# MacPherson       248000.0  285000.0  350000.0  161841.191091
# Marsiling        290000.0  340000.0  406800.0  122402.294444
# Marymount        380000.0  510000.0  650021.0  181087.105690
# Mattar           240000.0  284000.0  380000.0  135217.354518
# Mountbatten      412944.0  625000.0  750000.0  198319.002826
# Nicoll Highway   375250.0  408000.0  486950.0   63833.258453
# Novena           534500.0  540000.0  550000.0   24220.033031
# Outram Park      545000.0  760000.0  920000.0  219917.704507
# Pasir Ris        427125.0  485000.0  565000.0  100052.866966
# Paya Lebar       385000.0  476500.0  613750.0  148073.349417
# Pioneer          363000.0  419500.0  480000.0   81103.679500
# Potong Pasir     310000.0  400544.0  537250.0  158469.521959
# Punggol          420000.0  460000.0  520000.0   81880.659396
# Queenstown       375000.0  647444.0  772125.0  218906.750250
# Redhill          485000.0  686500.0  800000.0  188706.319350
# Rochor           348000.0  388000.0  435000.0   77991.946756
# Sembawang        360000.0  405500.0  460000.0   70836.537398
# Sengkang         395000.0  440000.0  500000.0   79336.681227
# Serangoon        385000.0  485000.0  606888.0  157299.619391
# Simei            418000.0  480000.0  545000.0   93459.383452
# Tai Seng         260000.0  335000.0  460000.0  137213.120844
# Tampines         398000.0  470000.0  566194.0  129858.407392
# Tampines East    390000.0  452000.0  521000.0   99714.691318
# Tampines West    370000.0  435000.0  520000.0  115480.391303
# Tan Kah Kee      543250.0  555000.0  579166.0   38520.260360
# Tanah Merah      325000.0  388888.0  494500.0  129591.982149
# Tanjong Pagar    500000.0  733000.0  889500.0  209032.338027
# Telok Blangah    370000.0  528000.0  645000.0  163464.759578
# Tiong Bahru      360000.0  598000.0  750000.0  218151.834207
# Toa Payoh        322000.0  570000.0  721825.0  216746.592534
# Ubi              352750.0  390000.0  439166.0  112488.636292
# Upper Changi     495000.0  595000.0  710000.0  118123.243783
# Woodlands        361250.0  425000.0  508000.0  121948.025166
# Woodlands North  265000.0  318000.0  390000.0   75873.542862
# Woodlands South  370000.0  410000.0  445000.0   59656.718561
# Woodleigh        342944.0  393800.0  512500.0   93487.327692
# Yew Tee          365000.0  415000.0  481000.0   82432.729530
# Yio Chu Kang     298000.0  345000.0  433000.0  126999.814777
# Yishun           302000.0  348000.0  412000.0   88683.406966
# one-north        350000.0  386500.0  668750.0  195963.864324

# %%
low_mrt = ['Admiralty', 'Bedok', 'Bedok North', 'Boon Lay', 'Braddell', 'Bukit Batok', 'Bukit Gombak','Bukit Panjang', 'Canberra', 'Cashew', 'Changi Airport', 'Chinatown', 'Chinese Garden', 'Choa Chu Kang', 'Clarke Quay', 'Hougang', 'Khatib', 'Lakeside', 'MacPherson', 'Marsiling', 'Mattar', 'Nicoll Highway', 'Pioneer', 'Rochor', 'Sembawang', 'Tai Seng', 'Tanah Merah', 'Ubi', 'Woodlands North', 'Woodlands South', 'Yew Tee', 'Yio Chu Kang', 'Yishun']
mid1_mrt = ['Aljunied', 'Ang Mo Kio', 'Bartley', 'Bedok Reservoir', 'Bencoolen', 'Botanic Gardens', 'Buangkok', 'Bugis', 'Clementi', 'Dakota', 'Geylang Bahru', 'HarbourFront', 'Jalan Besar', 'Jurong East', 'Kaki Bukit', 'Kovan', 'Little India', 'Pasir Ris', 'Paya Lebar', 'Potong Pasir', 'Punggol', 'Sengkang', 'Simei', 'Tampines', 'Tampines East', 'Tampines West', 'Woodlands', 'Woodleigh']
mid2_mrt = ['Boon Keng', 'Buona Vista', 'Commonwealth', 'Dover', 'Eunos', 'Farrer Park', 'Hillview', 'Holland Village', 'Kallang', 'Kembangan', 'Lavender', 'Lorong Chuan', 'Marymount', 'Mountbatten', 'Queenstown', 'Serangoon', 'Telok Blangah', 'Tiong Bahru', 'Toa Payoh', 'Upper Changi', 'one-north']
high_mrt = ['Beauty World', 'Bendemeer', 'Bishan', 'Bras Basah', 'Caldecott', 'Farrer Road', 'Labrador Park', 'Novena', 'Outram Park', 'Redhill', 'Tan Kah Kee', 'Tanjong Pagar']

# %%
replaceterm('mrt_name', low_mrt, 1)
replaceterm('mrt_name', mid1_mrt, 2)
replaceterm('mrt_name', mid2_mrt, 3)
replaceterm('mrt_name', high_mrt, 4)

# %%
data['mrt_name'].value_counts()
# Out:
# 1    68882
# 2    58745
# 3    18722
# 4     4285
# Name: mrt_name, dtype: int64

# %% [markdown]
# ### pri_sch_name

# %%
data.groupby('pri_sch_name')['resale_price'].apply(calculate_quantiles).unstack()
# Out:
#                                                  Q1        Q2        Q3  \
# pri_sch_name
# Admiralty Primary School                  374000.00  418000.0  470000.0
# Ahmad Ibrahim Primary School              280000.00  313500.0  360000.0
# Ai Tong School                            373500.00  531888.0  668444.0
# Alexandra Primary School                  389250.00  527500.0  737722.0
# Anchor Green Primary School               400000.00  443500.0  520000.0
# Anderson Primary School                   305000.00  355000.0  467375.0
# Ang Mo Kio Primary School                 305000.00  355000.0  428000.0
# Angsana Primary School                    375000.00  438000.0  510000.0
# Beacon Primary School                     345000.00  396000.0  450000.0
# Bedok Green Primary School                315000.00  382000.0  542000.0
# Bendemeer Primary School                  323000.00  372500.0  582000.0
# Blangah Rise Primary School               390500.00  540000.0  652600.0
# Boon Lay Garden Primary School            243000.00  295000.0  452250.0
# Bukit Panjang Primary School              309000.00  358000.0  460000.0
# Bukit View Primary School                 300000.00  377000.0  483500.0
# CHIJ                                      280000.00  340000.0  409500.0
# CHIJ Our Lady Queen of Peace              320000.00  342000.0  669000.0
# CHIJ Our Lady of Good Counsel             331572.00  448444.0  480000.0
# CHIJ Our Lady of The Nativity             390000.00  460000.0  580500.0
# CHIJ Primary                              333000.00  559000.0  700000.0
# CHIJ Saint Nicholas Girls' School         282000.00  335000.0  396972.0
# Canberra Primary School                   377000.00  425000.0  470000.0
# Canossa Catholic Primary School           238444.00  271000.0  309000.0
# Cantonment Primary School                 480000.00  716500.0  891000.0
# Casuarina Primary School                  416000.00  457500.0  563750.0
# Catholic High School                      540000.00  615000.0  800000.0
# Cedar Primary School                      298000.00  430000.0  580000.0
# Changkat Primary School                   480000.00  535000.0  617250.0
# Chongfu School                            290000.00  320000.0  365750.0
# Chongzheng Primary School                 335000.00  388000.0  468500.0
# Chua Chu Kang Primary School              350000.00  401000.0  456500.0
# Clementi Primary School                   370000.00  410000.0  510000.0
# Compassvale Primary School                420000.00  475000.0  532000.0
# Concord Primary School                    340000.00  385000.0  435000.0
# Corporation Primary School                342000.00  390000.0  430000.0
# Damai Primary School                      290000.00  336000.0  438888.0
# Dazhong Primary School                    288000.00  330000.0  386250.0
# De La Salle School                        385000.00  430000.0  508000.0
# East Spring Primary School                420000.00  478000.0  545000.0
# Edgefield Primary School                  410000.00  449500.0  505000.0
# Elias Park Primary School                 486500.00  540000.0  644166.0
# Endeavour Primary School                  345000.00  379000.0  410000.0
# Eunos Primary School                      315000.00  459944.0  618000.0
# Evergreen Primary School                  345000.00  390000.0  428000.0
# Fairfield Methodist School                410000.00  610000.0  735000.0
# Farrer Park Primary School                435750.00  500000.0  600000.0
# Fengshan Primary School                   302000.00  350000.0  420000.0
# Fern Green Primary School                 424000.00  455888.0  535000.0
# Fernvale Primary School                   400000.00  435000.0  470000.0
# First Toa Payoh Primary School            326000.00  390000.0  535000.0
# Frontier Primary School                   430000.00  470000.0  507375.0
# Fuchun Primary School                     325000.00  370000.0  450000.0
# Fuhua Primary School                      335000.00  385000.0  466500.0
# Gan Eng Seng Primary School               530000.00  680000.0  795000.0
# Geylang Methodist School                  348000.00  490000.0  620000.0
# Gongshang Primary School                  348000.00  415000.0  500000.0
# Greendale Primary School                  412000.00  445000.0  500000.0
# Greenridge Primary School                 350000.00  408000.0  450000.0
# Greenwood Primary School                  380000.00  418400.0  462750.0
# Guangyang Primary School                  388500.00  505000.0  640000.0
# Haig Girls' School                        385000.00  552500.0  660000.0
# Henry Park Primary School                 370000.00  528000.0  780000.0
# Holy Innocents' Primary School            306000.00  360000.0  460000.0
# Hong Wen School                           305000.00  450000.0  676888.0
# Horizon Primary School                    410000.00  448000.0  510000.0
# Hougang Primary School                    380000.00  435000.0  495000.0
# Huamin Primary School                     345000.00  400000.0  505000.0
# Innova Primary School                     383000.00  420000.0  460000.0
# Jiemin Primary School                     290000.00  325500.0  378000.0
# Jing Shan Primary School                  312444.00  370000.0  575694.0
# Junyuan Primary School                    386000.00  441333.0  517000.0
# Jurong Primary School                     315000.00  373000.0  477000.0
# Jurong West Primary School                405000.00  450000.0  495000.0
# Juying Primary School                     293500.00  328000.0  379250.0
# Keming Primary School                     335000.00  416000.0  515000.0
# Kheng Cheng School                        335000.00  590000.0  775000.0
# Kong Hwa School                           375000.00  588999.0  745000.0
# Kranji Primary School                     383500.00  433000.0  506750.0
# Kuo Chuan Presbyterian Primary School     500000.00  675000.0  760000.0
# Lakeside Primary School                   348000.00  430000.0  488000.0
# Lianhua Primary School                    280000.00  328000.0  426500.0
# Maha Bodhi School                         360000.00  400000.0  480000.0
# Maris Stella High School                  435000.00  580000.0  660000.0
# Marsiling Primary School                  268000.00  310000.0  370000.0
# Marymount Convent School                  275000.00  308000.0  358000.0
# Mayflower Primary School                  306494.00  355000.0  460000.0
# Mee Toh School                            375000.00  410000.0  460000.0
# Meridian Primary School                   413000.00  451000.0  500000.0
# Montfort Junior School                    370000.00  436500.0  550000.0
# Nan Chiau Primary School                  428375.00  475000.0  544722.0
# Nan Hua Primary School                    365000.00  493000.0  737500.0
# Nanyang Primary School                    415000.00  480888.0  587500.0
# Naval Base Primary School                 333000.00  390000.0  455000.0
# New Town Primary School                   319000.00  400000.0  610000.0
# Ngee Ann Primary School                   387000.00  442000.0  738500.0
# North Spring Primary School               385000.00  430000.0  490000.0
# North View Primary School                 305000.00  350000.0  400000.0
# North Vista Primary School                445000.00  500000.0  550000.0
# Northland Primary School                  330000.00  385000.0  435000.0
# Northoaks Primary School                  330000.00  372250.0  406500.0
# Oasis Primary School                      420000.00  448000.0  472500.0
# Opera Estate Primary School               300500.00  352000.0  532500.0
# Palm View Primary School                  393444.00  465000.0  567500.0
# Park View Primary School                  432250.00  490000.0  585000.0
# Pasir Ris Primary School                  440000.00  507000.0  565000.0
# Paya Lebar Methodist Girls' School        338000.00  415888.0  520000.0
# Pei Chun Public School                    270000.00  325000.0  560000.0
# Pei Hwa Presbyterian Primary School       675000.00  777500.0  915000.0
# Pei Tong Primary School                   357500.00  470000.0  650000.0
# Peiying Primary School                    339722.00  403500.0  493000.0
# Pioneer Primary School                    350000.00  390000.0  438000.0
# Poi Ching School                          445000.00  520000.0  600000.0
# Princess Elizabeth Primary School         300000.00  370000.0  470000.0
# Punggol Cove Primary School               468000.00  507500.0  549500.0
# Punggol Green Primary School              435000.00  488000.0  539166.0
# Punggol Primary School                    405000.00  448000.0  528000.0
# Punggol View Primary School               436000.00  475000.0  510000.0
# Qifa Primary School                       288000.00  331000.0  396000.0
# Qihua Primary School                      370000.00  463500.0  680000.0
# Queenstown Primary School                 391944.00  675000.0  788400.0
# Radin Mas Primary School                  335000.00  401000.0  553000.0
# Red Swastika School                       315000.00  390000.0  528000.0
# River Valley Primary School               273000.00  375000.0  700000.0
# Riverside Primary School                  328250.00  376500.0  415000.0
# Rivervale Primary School                  385000.00  430000.0  480000.0
# Rosyth School                             370000.00  438000.0  542250.0
# Rulang Primary School                     300000.00  350000.0  417000.0
# Saint Andrew's Junior School              333444.00  410000.0  511444.0
# Saint Anthony's Canossian Primary School  335000.00  430000.0  536000.0
# Saint Anthony's Primary School            318000.00  390000.0  475000.0
# Saint Gabriel's Primary School            365000.00  482000.0  488000.0
# Saint Hilda's Primary School              355000.00  425000.0  515000.0
# Saint Joseph's Institution Junior         580000.00  611000.0  634000.0
# Saint Margaret's Primary School           255000.00  305000.0  464250.0
# Saint Stephen's School                    308000.00  340000.0  455000.0
# Sembawang Primary School                  377500.00  430000.0  477000.0
# Seng Kang Primary School                  415000.00  460000.0  500000.0
# Sengkang Green Primary School             379000.00  425000.0  456750.0
# Shuqun Primary School                     319000.00  373000.0  435000.0
# Si Ling Primary School                    350000.00  415000.0  498000.0
# South View Primary School                 360000.00  410000.0  475000.0
# Springdale Primary School                 438000.00  473000.0  555000.0
# Stamford Primary School                   370000.00  410500.0  528000.0
# Tampines North Primary School             380500.00  465000.0  536500.0
# Tampines Primary School                   382000.00  473000.0  696500.0
# Tao Nan School                            405000.00  480000.0  580000.0
# Teck Ghee Primary School                  325000.00  399444.0  530000.0
# Teck Whye Primary School                  295000.00  335500.0  412000.0
# Telok Kurau Primary School                358000.00  418000.0  495000.0
# Temasek Primary School                    375000.00  435000.0  613500.0
# Townsville Primary School                 293000.00  340500.0  425750.0
# Unity Primary School                      355000.00  392000.0  445000.0
# Valour Primary School                     469500.00  515000.0  570500.0
# Waterway Primary School                   420000.00  456500.0  536500.0
# Wellington Primary School                 368000.00  415000.0  475000.0
# West Grove Primary School                 378000.00  442500.0  535000.0
# West Spring Primary School                410000.00  455000.0  530000.0
# West View Primary School                  418000.00  470000.0  535450.0
# Westwood Primary School                   400000.00  445000.0  509444.0
# White Sands Primary School                428000.00  475000.0  535000.0
# Woodgrove Primary School                  405000.00  440000.0  482500.0
# Woodlands Primary School                  360000.00  413000.0  455000.0
# Woodlands Ring Primary School             345000.00  385000.0  420000.0
# Xinghua Primary School                    333000.00  398000.0  518888.0
# Xingnan Primary School                    320000.00  359000.0  403450.0
# Xinmin Primary School                     310000.00  358000.0  433000.0
# Xishan Primary School                     312000.00  360000.0  428000.0
# Yangzheng Primary School                  385000.00  517000.0  632500.0
# Yew Tee Primary School                    380000.00  430000.0  508000.0
# Yio Chu Kang Primary School               380500.00  430000.0  488000.0
# Yishun Primary School                     300749.25  345000.0  435750.0
# Yu Neng Primary School                    300000.00  341000.0  412000.0
# Yuhua Primary School                      320000.00  438000.0  550000.0
# Yumin Primary School                      340000.00  381500.0  463000.0
# Zhangde Primary School                    407000.00  668000.0  770000.0
# Zhenghua Primary School                   342250.00  420500.0  500000.0
# Zhonghua Primary School                   361750.00  438000.0  510000.0
#
#                                                 Std Dev
# pri_sch_name
# Admiralty Primary School                   76159.834784
# Ahmad Ibrahim Primary School               62692.207293
# Ai Tong School                            175155.346419
# Alexandra Primary School                  199265.523261
# Anchor Green Primary School                79456.011223
# Anderson Primary School                   112441.544495
# Ang Mo Kio Primary School                 119102.891660
# Angsana Primary School                     92494.314361
# Beacon Primary School                      71691.796823
# Bedok Green Primary School                146973.241257
# Bendemeer Primary School                  160698.638137
# Blangah Rise Primary School               160220.780199
# Boon Lay Garden Primary School            121387.359697
# Bukit Panjang Primary School              114633.472030
# Bukit View Primary School                 130982.194528
# CHIJ                                      142697.687603
# CHIJ Our Lady Queen of Peace              186587.419022
# CHIJ Our Lady of Good Counsel             102333.313285
# CHIJ Our Lady of The Nativity             129173.403604
# CHIJ Primary                              206676.829129
# CHIJ Saint Nicholas Girls' School         118792.127001
# Canberra Primary School                    65218.402973
# Canossa Catholic Primary School           139190.062504
# Cantonment Primary School                 220067.194225
# Casuarina Primary School                  109369.246804
# Catholic High School                      174894.353534
# Cedar Primary School                      154079.157159
# Changkat Primary School                    98269.875863
# Chongfu School                             67895.709814
# Chongzheng Primary School                  77325.367662
# Chua Chu Kang Primary School               75747.380902
# Clementi Primary School                   174716.543736
# Compassvale Primary School                 77104.748566
# Concord Primary School                     69923.563974
# Corporation Primary School                 71736.041500
# Damai Primary School                      131378.802932
# Dazhong Primary School                     88057.161816
# De La Salle School                         92270.858946
# East Spring Primary School                 94557.869196
# Edgefield Primary School                   73054.434779
# Elias Park Primary School                 112137.988487
# Endeavour Primary School                   56571.998079
# Eunos Primary School                      167905.918246
# Evergreen Primary School                   65369.421973
# Fairfield Methodist School                181678.986106
# Farrer Park Primary School                108717.275882
# Fengshan Primary School                   108861.418784
# Fern Green Primary School                  78807.378746
# Fernvale Primary School                    64904.753962
# First Toa Payoh Primary School            153631.750595
# Frontier Primary School                    67183.661225
# Fuchun Primary School                     134613.867861
# Fuhua Primary School                      110721.757504
# Gan Eng Seng Primary School               191992.113327
# Geylang Methodist School                  167905.607621
# Gongshang Primary School                  101254.170300
# Greendale Primary School                   61209.896497
# Greenridge Primary School                  95006.247425
# Greenwood Primary School                   68292.544923
# Guangyang Primary School                  168780.099189
# Haig Girls' School                        159567.359405
# Henry Park Primary School                 222853.330022
# Holy Innocents' Primary School            135808.155689
# Hong Wen School                           223881.523279
# Horizon Primary School                     90880.711661
# Hougang Primary School                     82838.258863
# Huamin Primary School                     104425.236814
# Innova Primary School                      60128.901621
# Jiemin Primary School                      73910.667430
# Jing Shan Primary School                  176912.606190
# Junyuan Primary School                    111182.995162
# Jurong Primary School                     112529.646352
# Jurong West Primary School                 70785.788689
# Juying Primary School                      62104.526132
# Keming Primary School                     137086.115394
# Kheng Cheng School                        243092.903208
# Kong Hwa School                           209973.182249
# Kranji Primary School                      83652.806258
# Kuo Chuan Presbyterian Primary School     169671.395202
# Lakeside Primary School                   114273.008817
# Lianhua Primary School                    126507.962974
# Maha Bodhi School                         134886.841967
# Maris Stella High School                  195649.652595
# Marsiling Primary School                  106558.419041
# Marymount Convent School                   58709.712389
# Mayflower Primary School                  146959.475659
# Mee Toh School                             74363.412208
# Meridian Primary School                    68503.508749
# Montfort Junior School                    134648.531144
# Nan Chiau Primary School                   79317.918269
# Nan Hua Primary School                    199938.618229
# Nanyang Primary School                    178232.110808
# Naval Base Primary School                 100171.598448
# New Town Primary School                   198461.449558
# Ngee Ann Primary School                   188638.482838
# North Spring Primary School                76968.751122
# North View Primary School                  81039.778327
# North Vista Primary School                 74158.929687
# Northland Primary School                  111641.067138
# Northoaks Primary School                   63573.318313
# Oasis Primary School                       76777.194422
# Opera Estate Primary School               146918.576644
# Palm View Primary School                  116189.581170
# Park View Primary School                   93312.810545
# Pasir Ris Primary School                   91391.029275
# Paya Lebar Methodist Girls' School        145385.460110
# Pei Chun Public School                    172443.620810
# Pei Hwa Presbyterian Primary School       144623.957462
# Pei Tong Primary School                   172640.876419
# Peiying Primary School                    106357.871671
# Pioneer Primary School                     71500.741014
# Poi Ching School                          109215.243158
# Princess Elizabeth Primary School         125654.435680
# Punggol Cove Primary School                96814.004106
# Punggol Green Primary School               95018.728827
# Punggol Primary School                    112601.739249
# Punggol View Primary School                69131.520379
# Qifa Primary School                        87722.125428
# Qihua Primary School                      165243.057936
# Queenstown Primary School                 220763.946466
# Radin Mas Primary School                  141252.568814
# Red Swastika School                       118487.515675
# River Valley Primary School               219483.259700
# Riverside Primary School                   64329.832541
# Rivervale Primary School                   70584.665594
# Rosyth School                             130103.170037
# Rulang Primary School                      94583.305125
# Saint Andrew's Junior School              150588.065296
# Saint Anthony's Canossian Primary School  130429.843052
# Saint Anthony's Primary School            106459.216715
# Saint Gabriel's Primary School             69480.932636
# Saint Hilda's Primary School              122700.765569
# Saint Joseph's Institution Junior          50697.398179
# Saint Margaret's Primary School           142922.152639
# Saint Stephen's School                    166893.088161
# Sembawang Primary School                   68362.715313
# Seng Kang Primary School                   64905.148446
# Sengkang Green Primary School              78129.961706
# Shuqun Primary School                     105366.760133
# Si Ling Primary School                    105493.905700
# South View Primary School                  86260.182155
# Springdale Primary School                  77133.440619
# Stamford Primary School                   142906.654052
# Tampines North Primary School             107886.691488
# Tampines Primary School                   161689.115106
# Tao Nan School                            168908.399531
# Teck Ghee Primary School                  148075.508116
# Teck Whye Primary School                   96748.680848
# Telok Kurau Primary School                123405.703731
# Temasek Primary School                    138381.190214
# Townsville Primary School                 108859.485190
# Unity Primary School                       62764.316945
# Valour Primary School                      94533.217082
# Waterway Primary School                    77508.953108
# Wellington Primary School                  77888.400914
# West Grove Primary School                  91132.318772
# West Spring Primary School                 91091.136477
# West View Primary School                   99651.832540
# Westwood Primary School                    77658.116037
# White Sands Primary School                 78607.983264
# Woodgrove Primary School                   62404.099428
# Woodlands Primary School                   88315.589029
# Woodlands Ring Primary School              64137.224399
# Xinghua Primary School                    160007.489043
# Xingnan Primary School                     61706.376597
# Xinmin Primary School                     108765.613647
# Xishan Primary School                      78996.810321
# Yangzheng Primary School                  171771.425243
# Yew Tee Primary School                     95083.939278
# Yio Chu Kang Primary School                85828.903888
# Yishun Primary School                      82516.140720
# Yu Neng Primary School                    106672.855908
# Yuhua Primary School                      152795.904093
# Yumin Primary School                       75798.437766
# Zhangde Primary School                    207619.976375
# Zhenghua Primary School                   108961.092485
# Zhonghua Primary School                   127941.534361

# %%
low_pri = data.groupby('pri_sch_name')['resale_price'].apply(calculate_quantiles).unstack()[data.groupby('pri_sch_name')['resale_price'].apply(calculate_quantiles).unstack()['Q3']<550000].index.tolist()
mid1_pri = ['Anchor Green Primary School', 'Montfort Junior School', 'North Vista Primary School', 'Yuhua Primary School', 'Springdale Primary School', 'Pei Chun Public School', 'Casuarina Primary School', 'Pasir Ris Primary School', 'Palm View Primary School', 'Jing Shan Primary School', 'Cedar Primary School', 'Tao Nan School', 'CHIJ Our Lady of The Nativity', 'Bendemeer Primary School', 'Park View Primary School', 'Nanyang Primary School', 'Farrer Park Primary School', 'Poi Ching School', 'Radin Mas Primary School']
mid2_pri = ['New Town Primary School', 'Temasek Primary School', 'Eunos Primary School','Geylang Methodist School', 'Yangzheng Primary School', 'Guangyang Primary School', 'Pei Tong Primary School', 'Blangah Rise Primary School', 'Haig Girls\' School', 'Maris Stella High School', 'Ai Tong School', 'CHIJ Our Lady Queen of Peace', 'Hong Wen School', 'Qihua Primary School', 'Tampines Primary School', 'CHIJ Primary', 'River Valley Primary School', 'Fairfield Methodist School', 'Nan Hua Primary School', 'Alexandra Primary School', 'Ngee Ann Primary School', 'Kong Hwa School', 'Zhangde Primary School', 'Kheng Cheng School', 'Henry Park Primary School', 'Queenstown Primary School']
high_pri = data.groupby('pri_sch_name')['resale_price'].apply(calculate_quantiles).unstack()[data.groupby('pri_sch_name')['resale_price'].apply(calculate_quantiles).unstack()['Q1']>468000].index.tolist()

# %%
replaceterm('pri_sch_name', low_pri, 'low')
replaceterm('pri_sch_name', mid1_pri, 'mid1')
replaceterm('pri_sch_name', mid2_pri, 'mid2')
replaceterm('pri_sch_name', high_pri, 'high')

# %% [markdown]
# ### sec_sch_name

# %%
data.groupby('sec_sch_name')['resale_price'].apply(calculate_quantiles).unstack()
# Out:
#                                                   Q1        Q2        Q3  \
# sec_sch_name
# Admiralty Secondary School                  360000.0  400000.0  441888.0
# Ahmad Ibrahim Secondary School              280000.0  315000.0  365000.0
# Anderson Secondary School                   311000.0  373000.0  629500.0
# Ang Mo Kio Secondary School                 335000.0  428400.0  578000.0
# Anglican High School                        300000.0  345000.0  414500.0
# Anglo-Chinese School                        590000.0  622500.0  644750.0
# Assumption English School                   328750.0  369750.0  608750.0
# Bartley Secondary School                    260000.0  320000.0  538750.0
# Beatty Secondary School                     280000.0  346000.0  578000.0
# Bedok Green Secondary School                305000.0  370000.0  515000.0
# Bedok View Secondary School                 350000.0  415000.0  555000.0
# Bendemeer Secondary School                  316000.0  438000.0  625000.0
# Boon Lay Secondary School                   388000.0  435000.0  500000.0
# Bowen Secondary School                      400000.0  483500.0  602750.0
# Broadrick Secondary School                  445000.0  650400.0  790000.0
# Bukit Batok Secondary School                305000.0  360000.0  486500.0
# Bukit Merah Secondary School                448000.0  600000.0  710916.0
# Bukit Panjang Government High School        348750.0  395000.0  450000.0
# Bukit View Secondary School                 343000.0  443000.0  548444.0
# CHIJ Katong Convent                         407000.0  525000.0  789000.0
# CHIJ Saint Joseph's Convent                 375000.0  415000.0  469444.0
# CHIJ Saint Nicholas Girls' School           282000.0  338000.0  397888.0
# CHIJ Saint Theresa's Convent                325000.0  405000.0  600000.0
# CHIJ Secondary                              380000.0  655000.0  788000.0
# Canberra Secondary School                   352000.0  390000.0  444944.0
# Catholic High School                        570000.0  633000.0  797250.0
# Cedar Girls' Secondary School               268000.0  316500.0  542500.0
# Changkat Changi Secondary School            452000.0  510000.0  575000.0
# Christ Church Secondary School              390000.0  425000.0  464000.0
# Chua Chu Kang Secondary School              328944.0  382000.0  450000.0
# Chung Cheng High School                     432500.0  501500.0  663750.0
# Clementi Town Secondary School              360000.0  425000.0  578000.0
# Commonwealth Secondary School               310000.0  370000.0  445000.0
# Compassvale Secondary School                416972.0  470944.0  530000.0
# Crescent Girls' School                      740000.0  793000.0  838000.0
# Damai Secondary School                      295000.0  336750.0  430000.0
# Deyi Secondary School                       308000.0  358000.0  447000.0
# Dunearn Secondary School                    281000.0  325000.0  370500.0
# Dunman High School                          270000.0  330000.0  560000.0
# Dunman Secondary School                     393000.0  448444.0  505000.0
# East Spring Secondary School                405000.0  446500.0  509500.0
# Edgefield Secondary School                  440000.0  490000.0  540916.0
# Evergreen Secondary School                  350000.0  395000.0  435000.0
# Fairfield Methodist School                  385250.0  580000.0  754000.0
# Fajar Secondary School                      365000.0  500000.0  597500.0
# Fuchun Secondary School                     335000.0  392000.0  480000.0
# Fuhua Secondary School                      310000.0  365000.0  430000.0
# Gan Eng Seng School                         385000.0  590000.0  770000.0
# Geylang Methodist School                    271750.0  348000.0  548000.0
# Greendale Secondary School                  400000.0  440000.0  500000.0
# Greenridge Secondary School                 330000.0  373000.0  434500.0
# Guangyang Secondary School                  412800.0  515000.0  650000.0
# Hai Sing Catholic School                    440000.0  520000.0  659500.0
# Hillgrove Secondary School                  280000.0  335000.0  443950.0
# Holy Innocents' High School                 345000.0  415000.0  496000.0
# Hong Kah Secondary School                   308500.0  355000.0  400000.0
# Hougang Secondary School                    383500.0  435000.0  495000.0
# Hua Yi Secondary School                     330000.0  380000.0  440000.0
# Junyuan Secondary School                    425000.0  488000.0  570000.0
# Jurong Secondary School                     287000.0  400000.0  495000.0
# Jurong West Secondary School                428000.0  468000.0  505000.0
# Jurongville Secondary School                341000.0  440000.0  540000.0
# Juying Secondary School                     320000.0  356250.0  403666.0
# Kent Ridge Secondary School                 300000.0  346000.0  430000.0
# Kranji Secondary School                     355000.0  418000.0  460000.0
# Kuo Chuan Presbyterian Secondary School     500000.0  680000.0  760000.0
# Loyang Secondary School                     420000.0  465000.0  522000.0
# Manjusri Secondary School                   358000.0  435000.0  565000.0
# Marsiling Secondary School                  300000.0  343000.0  390000.0
# Mayflower Secondary School                  306750.0  360000.0  437250.0
# Meridian Secondary School                   435000.0  498000.0  558000.0
# Methodist Girls' School                     672750.0  777500.0  917250.0
# Montfort Secondary School                   370000.0  422000.0  510000.0
# Nan Chiau High School                       416444.0  465000.0  543000.0
# Nan Hua High School                         380000.0  555000.0  698000.0
# Naval Base Secondary School                 320000.0  380000.0  466500.0
# New Town Secondary School                   368000.0  488000.0  656125.0
# Ngee Ann Secondary School                   375000.0  443000.0  525000.0
# North Vista Secondary School                430000.0  490444.0  553000.0
# Northbrooks Secondary School                320000.0  375000.0  425000.0
# Northland Secondary School                  308000.0  355000.0  420000.0
# Orchid Park Secondary School                335000.0  391500.0  460000.0
# Outram Secondary School                     470000.0  685000.0  840000.0
# Pasir Ris Crest Secondary School            420500.0  475000.0  565000.0
# Pasir Ris Secondary School                  342000.0  400000.0  490000.0
# Paya Lebar Methodist Girls' School          355000.0  424888.0  525000.0
# Pei Hwa Secondary School                    390000.0  430000.0  465000.0
# Peicai Secondary School                     373750.0  455000.0  513500.0
# Peirce Secondary School                     480750.0  570000.0  693750.0
# Ping Yi Secondary School                    308000.0  370000.0  445000.0
# Presbyterian High School                    318250.0  411888.0  500000.0
# Punggol Secondary School                    422000.0  450000.0  490000.0
# Queenstown Secondary School                 675000.0  750000.0  828000.0
# Queensway Secondary School                  315000.0  388000.0  610000.0
# Raffles Girls' School                       380000.0  440000.0  536291.0
# Raffles Institution                         305000.0  375000.0  524000.0
# Regent Secondary School                     385250.0  440000.0  525000.0
# River Valley High School                    248000.0  307000.0  438000.0
# Riverside Secondary School                  397500.0  465000.0  559250.0
# Saint Andrew's Secondary School             328950.0  390000.0  510000.0
# Saint Anthony's Canossian Secondary School  388500.0  500000.0  578500.0
# Saint Gabriel's Secondary School            361500.0  568000.0  650750.0
# Saint Hilda's Secondary School              360000.0  430000.0  510000.0
# Saint Margaret's Secondary School           415000.0  480888.0  587500.0
# Saint Patrick's School                      395000.0  463800.0  550000.0
# Sembawang Secondary School                  379750.0  428888.0  480000.0
# Seng Kang Secondary School                  428000.0  470000.0  535000.0
# Serangoon Garden Secondary School           336250.0  398500.0  515000.0
# Serangoon Secondary School                  460000.0  550000.0  650000.0
# Springfield Secondary School                426000.0  527000.0  665000.0
# Swiss Cottage Secondary School              335000.0  414500.0  495000.0
# Tampines Secondary School                   362500.0  443888.0  550000.0
# Tanglin Secondary School                    285750.0  325000.0  382750.0
# Tanjong Katong Secondary School             370000.0  483000.0  643000.0
# Teck Whye Secondary School                  310000.0  350000.0  440000.0
# Temasek Junior College                      314000.0  375000.0  630000.0
# Temasek Secondary School                    420500.0  513888.0  675000.0
# Unity Secondary School                      363000.0  410000.0  475000.0
# West Spring Secondary School                408000.0  452500.0  495000.0
# Westwood Secondary School                   365972.0  399444.0  455000.0
# Whitley Secondary School                    510000.0  598000.0  812000.0
# Woodgrove Secondary School                  375000.0  413000.0  453000.0
# Woodlands Ring Secondary School             358000.0  400000.0  448888.0
# Woodlands Secondary School                  255000.0  292000.0  336666.0
# Xinmin Secondary School                     313916.0  365000.0  440000.0
# Yio Chu Kang Secondary School               298000.0  340000.0  428666.0
# Yishun Secondary School                     290000.0  322000.0  372000.0
# Yishun Town Secondary School                315000.0  365000.0  440000.0
# Yuan Ching Secondary School                 385000.0  443000.0  488000.0
# Yuhua Secondary School                      308000.0  360000.0  450000.0
# Yusof Ishak Secondary School                388666.0  459500.0  580000.0
# Yuying Secondary School                     300000.0  362000.0  469722.0
# Zhenghua Secondary School                   372850.0  425000.0  495000.0
# Zhonghua Secondary School                   379500.0  488000.0  575000.0
#
#                                                   Std Dev
# sec_sch_name
# Admiralty Secondary School                   69472.705518
# Ahmad Ibrahim Secondary School               66017.866440
# Anderson Secondary School                   191267.230606
# Ang Mo Kio Secondary School                 162905.574947
# Anglican High School                         90427.267551
# Anglo-Chinese School                         42973.567457
# Assumption English School                   169413.746675
# Bartley Secondary School                    170247.850513
# Beatty Secondary School                     187913.145628
# Bedok Green Secondary School                125521.988958
# Bedok View Secondary School                 120986.008918
# Bendemeer Secondary School                  193203.292436
# Boon Lay Secondary School                    82621.020379
# Bowen Secondary School                      122645.456865
# Broadrick Secondary School                  194097.852501
# Bukit Batok Secondary School                129536.972266
# Bukit Merah Secondary School                173329.314076
# Bukit Panjang Government High School         73902.533401
# Bukit View Secondary School                 144134.602443
# CHIJ Katong Convent                         193676.729155
# CHIJ Saint Joseph's Convent                  73639.489050
# CHIJ Saint Nicholas Girls' School            93962.097546
# CHIJ Saint Theresa's Convent                173337.717307
# CHIJ Secondary                              224900.617514
# Canberra Secondary School                    66483.026380
# Catholic High School                        132184.963763
# Cedar Girls' Secondary School               174883.995594
# Changkat Changi Secondary School             99278.975602
# Christ Church Secondary School               61022.530882
# Chua Chu Kang Secondary School               96770.625552
# Chung Cheng High School                     119774.703472
# Clementi Town Secondary School              180785.485124
# Commonwealth Secondary School                95220.470909
# Compassvale Secondary School                 78856.146665
# Crescent Girls' School                       60574.683951
# Damai Secondary School                      134719.890586
# Deyi Secondary School                       117906.471050
# Dunearn Secondary School                     80655.928188
# Dunman High School                          193836.725145
# Dunman Secondary School                      93510.358898
# East Spring Secondary School                 83174.619569
# Edgefield Secondary School                   89948.519275
# Evergreen Secondary School                   77811.758311
# Fairfield Methodist School                  202393.085219
# Fajar Secondary School                      132495.935630
# Fuchun Secondary School                     132142.457884
# Fuhua Secondary School                       99568.262247
# Gan Eng Seng School                         217898.941332
# Geylang Methodist School                    176186.710685
# Greendale Secondary School                   74126.577856
# Greenridge Secondary School                  78130.245512
# Guangyang Secondary School                  165062.089171
# Hai Sing Catholic School                    120468.029885
# Hillgrove Secondary School                  131830.075580
# Holy Innocents' High School                 129319.986459
# Hong Kah Secondary School                    80556.955132
# Hougang Secondary School                     85021.448797
# Hua Yi Secondary School                      83779.255033
# Junyuan Secondary School                    111948.503891
# Jurong Secondary School                     131159.657064
# Jurong West Secondary School                 64412.971179
# Jurongville Secondary School                119338.908950
# Juying Secondary School                      64462.424830
# Kent Ridge Secondary School                 102009.468396
# Kranji Secondary School                      74946.030920
# Kuo Chuan Presbyterian Secondary School     169366.165103
# Loyang Secondary School                      78056.611658
# Manjusri Secondary School                   149090.967203
# Marsiling Secondary School                  118537.985205
# Mayflower Secondary School                  129841.546943
# Meridian Secondary School                    98167.317614
# Methodist Girls' School                     148060.092927
# Montfort Secondary School                   124547.490564
# Nan Chiau High School                        86552.060011
# Nan Hua High School                         172413.604801
# Naval Base Secondary School                 105477.321819
# New Town Secondary School                   163449.930237
# Ngee Ann Secondary School                   106893.519189
# North Vista Secondary School                 87551.869418
# Northbrooks Secondary School                 97817.636544
# Northland Secondary School                   84674.529182
# Orchid Park Secondary School                111456.690220
# Outram Secondary School                     226740.462151
# Pasir Ris Crest Secondary School             94584.500839
# Pasir Ris Secondary School                  103446.241990
# Paya Lebar Methodist Girls' School          131299.149999
# Pei Hwa Secondary School                     73447.538135
# Peicai Secondary School                     136135.893691
# Peirce Secondary School                     158810.223289
# Ping Yi Secondary School                    117857.030234
# Presbyterian High School                    113596.112011
# Punggol Secondary School                     76085.770247
# Queenstown Secondary School                 131197.555401
# Queensway Secondary School                  205483.699635
# Raffles Girls' School                       131243.680307
# Raffles Institution                         183246.326141
# Regent Secondary School                      84334.951644
# River Valley High School                    115333.035882
# Riverside Secondary School                  129549.020293
# Saint Andrew's Secondary School             143222.684016
# Saint Anthony's Canossian Secondary School  135925.969768
# Saint Gabriel's Secondary School            178151.122186
# Saint Hilda's Secondary School              124219.577612
# Saint Margaret's Secondary School           178232.110808
# Saint Patrick's School                      159432.808233
# Sembawang Secondary School                   72448.113762
# Seng Kang Secondary School                   74755.984355
# Serangoon Garden Secondary School           132833.986667
# Serangoon Secondary School                  122173.781861
# Springfield Secondary School                131181.471708
# Swiss Cottage Secondary School              104037.625572
# Tampines Secondary School                   145662.559550
# Tanglin Secondary School                     71598.807262
# Tanjong Katong Secondary School             144749.390194
# Teck Whye Secondary School                   94066.308286
# Temasek Junior College                      171282.076950
# Temasek Secondary School                    139232.376820
# Unity Secondary School                       81825.529229
# West Spring Secondary School                 73228.617052
# Westwood Secondary School                    68926.873493
# Whitley Secondary School                    216950.689421
# Woodgrove Secondary School                   62141.607285
# Woodlands Ring Secondary School              79212.117944
# Woodlands Secondary School                   61650.871373
# Xinmin Secondary School                     104357.962310
# Yio Chu Kang Secondary School               140313.701845
# Yishun Secondary School                      72760.682959
# Yishun Town Secondary School                 93328.383329
# Yuan Ching Secondary School                  85535.897091
# Yuhua Secondary School                      123526.072048
# Yusof Ishak Secondary School                153248.596002
# Yuying Secondary School                     157250.711077
# Zhenghua Secondary School                   101024.802060
# Zhonghua Secondary School                   166787.728571

# %%
low_sec = ['Woodlands Secondary School','Ahmad Ibrahim Secondary School','Dunearn Secondary School','Yishun Secondary School','Tanglin Secondary School','Marsiling Secondary School','CHIJ Saint Nicholas Girls\' School','Hong Kah Secondary School','Juying Secondary School','Anglican High School','Northland Secondary School','Northbrooks Secondary School','Yio Chu Kang Secondary School','Damai Secondary School','Fuhua Secondary School','Kent Ridge Secondary School','Greenridge Secondary School','Evergreen Secondary School','Mayflower Secondary School','River Valley High School','Hua Yi Secondary School','Teck Whye Secondary School','Xinmin Secondary School','Yishun Town Secondary School','Admiralty Secondary School','Hillgrove Secondary School','Canberra Secondary School','Commonwealth Secondary School','Ping Yi Secondary School','Deyi Secondary School','Woodlands Ring Secondary School','Bukit Panjang Government High School','Chua Chu Kang Secondary School','Yuhua Secondary School','Woodgrove Secondary School','Westwood Secondary School','Kranji Secondary School','Orchid Park Secondary School','Christ Church Secondary School','Pei Hwa Secondary School','Naval Base Secondary School','CHIJ Saint Joseph\'s Convent','Yuying Secondary School','Unity Secondary School','Fuchun Secondary School','Sembawang Secondary School','Bukit Batok Secondary School','Yuan Ching Secondary School','Pasir Ris Secondary School','Punggol Secondary School','Hougang Secondary School','Jurong Secondary School','Swiss Cottage Secondary School','West Spring Secondary School','Zhenghua Secondary School','Holy Innocents\' High School','Boon Lay Secondary School','Greendale Secondary School','Presbyterian High School','Dunman Secondary School','Jurong West Secondary School','East Spring Secondary School','Montfort Secondary School','Saint Andrew\'s Secondary School','Saint Hilda\'s Secondary School','Peicai Secondary School','Bedok Green Secondary School','Serangoon Garden Secondary School','Loyang Secondary School','Raffles Institution','Ngee Ann Secondary School','Paya Lebar Methodist Girls\' School','Regent Secondary School','Compassvale Secondary School','Seng Kang Secondary School','Raffles Girls\' School','Bartley Secondary School','Jurongville Secondary School','Edgefield Secondary School','Cedar Girls\' Secondary School','Nan Chiau High School','Geylang Methodist School','Bukit View Secondary School']
mid1_sec = ['Saint Patrick\'s School','Tampines Secondary School','North Vista Secondary School','Bedok View Secondary School','Meridian Secondary School','Riverside Secondary School','Dunman High School','Pasir Ris Crest Secondary School','Manjusri Secondary School','Junyuan Secondary School','Changkat Changi Secondary School','Zhonghua Secondary School','Clementi Town Secondary School','Ang Mo Kio Secondary School','Beatty Secondary School','Saint Anthony\'s Canossian Secondary School','Yusof Ishak Secondary School','Saint Margaret\'s Secondary School','Fajar Secondary School']
mid2_sec = ['CHIJ Saint Theresa\'s Convent','Bowen Secondary School','Assumption English School','Queensway Secondary School','Bendemeer Secondary School','Anderson Secondary School','Temasek Junior College','Tanjong Katong Secondary School','Serangoon Secondary School','Guangyang Secondary School','Saint Gabriel\'s Secondary School','New Town Secondary School','Hai Sing Catholic School','Chung Cheng High School','Springfield Secondary School','Temasek Secondary School','Peirce Secondary School','Nan Hua High School','Bukit Merah Secondary School','Fairfield Methodist School','Gan Eng Seng School','CHIJ Secondary','CHIJ Katong Convent','Broadrick Secondary School','Outram Secondary School']
high_sec = ['Crescent Girls\' School','Queenstown Secondary School','Methodist Girls\' School','Anglo-Chinese School','Catholic High School','Whitley Secondary School','Kuo Chuan Presbyterian Secondary School']

# %%
replaceterm('sec_sch_name', low_sec, 'low')
replaceterm('sec_sch_name', mid1_sec, 'mid1')
replaceterm('sec_sch_name', mid2_sec, 'mid2')
replaceterm('sec_sch_name', high_sec, 'high')

# %% [markdown]
# ### dummify

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150634 entries, 0 to 150633
# Data columns (total 50 columns):
#  #   Column                     Non-Null Count   Dtype
# ---  ------                     --------------   -----
#  0   flat_type                  150634 non-null  object
#  1   storey_range               150634 non-null  int64
#  2   floor_area_sqm             150634 non-null  float64
#  3   flat_model                 150634 non-null  object
#  4   resale_price               150634 non-null  float64
#  5   tranc_year                 150634 non-null  int64
#  6   tranc_month                150634 non-null  int64
#  7   lower                      150634 non-null  int64
#  8   upper                      150634 non-null  int64
#  9   mid                        150634 non-null  int64
#  10  hdb_age                    150634 non-null  int64
#  11  max_floor_lvl              150634 non-null  int64
#  12  commercial                 150634 non-null  object
#  13  market_hawker              150634 non-null  object
#  14  multistorey_carpark        150634 non-null  object
#  15  total_dwelling_units       150634 non-null  int64
#  16  1room_sold                 150634 non-null  int64
#  17  2room_sold                 150634 non-null  int64
#  18  3room_sold                 150634 non-null  int64
#  19  4room_sold                 150634 non-null  int64
#  20  5room_sold                 150634 non-null  int64
#  21  exec_sold                  150634 non-null  int64
#  22  multigen_sold              150634 non-null  int64
#  23  studio_apartment_sold      150634 non-null  int64
#  24  1room_rental               150634 non-null  int64
#  25  2room_rental               150634 non-null  int64
#  26  3room_rental               150634 non-null  int64
#  27  other_room_rental          150634 non-null  int64
#  28  planning_area              150634 non-null  object
#  29  mall_nearest_distance      150634 non-null  float64
#  30  mall_within_500m           150634 non-null  float64
#  31  mall_within_1km            150634 non-null  float64
#  32  mall_within_2km            150634 non-null  float64
#  33  hawker_nearest_distance    150634 non-null  float64
#  34  hawker_within_500m         150634 non-null  float64
#  35  hawker_within_1km          150634 non-null  float64
#  36  hawker_within_2km          150634 non-null  float64
#  37  hawker_food_stalls         150634 non-null  int64
#  38  hawker_market_stalls       150634 non-null  int64
#  39  mrt_nearest_distance       150634 non-null  float64
#  40  mrt_name                   150634 non-null  int64
#  41  mrt_interchange            150634 non-null  int64
#  42  bus_stop_nearest_distance  150634 non-null  float64
#  43  pri_sch_nearest_distance   150634 non-null  float64
#  44  pri_sch_name               150634 non-null  object
#  45  vacancy                    150634 non-null  int64
#  46  pri_sch_affiliation        150634 non-null  int64
#  47  sec_sch_nearest_dist       150634 non-null  float64
#  48  sec_sch_name               150634 non-null  object
#  49  cutoff_point               150634 non-null  int64
# dtypes: float64(14), int64(28), object(8)
# memory usage: 57.5+ MB

# %%
data['sec_sch_name']
# Out:
# 0          low
# 1         high
# 2         mid1
# 3         high
# 4          low
#           ...
# 150629     low
# 150630     low
# 150631    mid1
# 150632    mid2
# 150633     low
# Name: sec_sch_name, Length: 150634, dtype: object

# %%
encoded_data = pd.get_dummies(data, columns=['1room_sold', 'mrt_interchange', 'pri_sch_affiliation', 'planning_area', 'flat_model', 'flat_type', 'multistorey_carpark', 'commercial', 'market_hawker', 'pri_sch_name', 'sec_sch_name'], drop_first=True)

# %% [markdown]
# ### Creating interactions terms

# %%
encoded_data.shape
# Out:
# (150634, 58)

# %%
encoded_data['sqm_year_max_floor'] = encoded_data['floor_area_sqm'] * encoded_data['tranc_year'] * encoded_data['max_floor_lvl']
encoded_data['max_floor_5room'] = encoded_data['max_floor_lvl'] * encoded_data['5room_sold']
encoded_data['age_3room'] = encoded_data['hdb_age'] * encoded_data['3room_sold']
encoded_data['floor_hawker2km'] = encoded_data['mid'] * encoded_data['hawker_within_2km']

# %%
encoded_data['age_totalunit'] = encoded_data['hdb_age'] * encoded_data['total_dwelling_units']
encoded_data['year_floor'] = encoded_data['tranc_year'] * encoded_data['mid']
encoded_data['maxfloor_secsch'] = encoded_data['max_floor_lvl'] * encoded_data['sec_sch_nearest_dist']
encoded_data['year_age'] = encoded_data['tranc_year'] * encoded_data['hdb_age']

# %%
encoded_data['age_execsold'] = encoded_data['hdb_age'] * encoded_data['exec_sold']
encoded_data['age_pri_sch'] = encoded_data['hdb_age'] * encoded_data['pri_sch_nearest_distance']
encoded_data['floor_hawker'] = encoded_data['mid'] * encoded_data['hawker_market_stalls']
encoded_data['floor_mall1km'] = encoded_data['mid'] * encoded_data['mall_within_1km']

# %%
encoded_data['which_floor'] = encoded_data['mid'] * encoded_data['storey_range']
encoded_data['floor_maxfloor'] = encoded_data['max_floor_lvl'] * encoded_data['which_floor']

# %%
selected_col = ['floor_area_sqm', 'pri_sch_name_low','max_floor_lvl', 'flat_model_low', 'sec_sch_name_low', 'hdb_age', 'hawker_within_2km',
'mrt_nearest_distance', 'flat_model_mid', 'mrt_name', 'mid', 'planning_area_low', 'sec_sch_nearest_dist',
'mall_within_2km', 'sqm_year_max_floor', 'max_floor_5room', 'age_3room', 'floor_hawker2km', 'age_totalunit', 'year_floor', 'maxfloor_secsch', 'year_age', 'age_execsold', 'age_pri_sch', 'floor_hawker', 'floor_mall1km', 'storey_range', 'which_floor', 'floor_maxfloor']

# %%
X = encoded_data[selected_col]
y = data['resale_price']

# %%
X.skew().sort_values()
# Out:
# flat_model_low         -2.912722
# pri_sch_name_low       -0.967164
# sec_sch_name_low       -0.850126
# hdb_age                -0.196927
# year_age               -0.196583
# planning_area_low       0.133869
# floor_area_sqm          0.271862
# mrt_name                0.879497
# hawker_within_2km       1.145569
# mrt_nearest_distance    1.146725
# storey_range            1.191352
# sqm_year_max_floor      1.357442
# mid                     1.557997
# year_floor              1.559332
# sec_sch_nearest_dist    1.812095
# max_floor_lvl           2.029228
# age_pri_sch             2.254331
# age_totalunit           2.421883
# age_3room               2.704827
# flat_model_mid          2.975420
# max_floor_5room         3.026984
# maxfloor_secsch         3.088535
# floor_hawker            3.159103
# floor_mall1km           3.493342
# floor_hawker2km         3.732120
# age_execsold            3.914698
# which_floor             4.115707
# mall_within_2km         4.634232
# floor_maxfloor          7.407588
# dtype: float64

# %%
min(encoded_data['max_floor_5room'])
# Out:
# 0

# %%
skew_list_log = ['floor_maxfloor', 'which_floor', 'maxfloor_secsch']

for x in skew_list_log:
    X[x] = np.log(X[x])

# %%
skew_list = ['mall_within_2km', 'age_execsold', 'floor_hawker2km', 'floor_mall1km', 'floor_hawker', 'max_floor_5room']

for x in skew_list:
    X[x] = np.sqrt(X[x])

# %%
X.skew()
# Out:
# floor_area_sqm          0.271862
# pri_sch_name_low       -0.967164
# max_floor_lvl           2.029228
# flat_model_low         -2.912722
# sec_sch_name_low       -0.850126
# hdb_age                -0.196927
# hawker_within_2km       1.145569
# mrt_nearest_distance    1.146725
# flat_model_mid          2.975420
# mrt_name                0.879497
# mid                     1.557997
# planning_area_low       0.133869
# sec_sch_nearest_dist    1.812095
# mall_within_2km         1.281302
# sqm_year_max_floor      1.357442
# max_floor_5room         0.880558
# age_3room               2.704827
# floor_hawker2km         1.275237
# age_totalunit           2.421883
# year_floor              1.559332
# maxfloor_secsch        -0.014426
# year_age               -0.196583
# age_execsold            2.902259
# age_pri_sch             2.254331
# floor_hawker            0.554548
# floor_mall1km           0.553888
# storey_range            1.191352
# which_floor             0.013269
# floor_maxfloor          0.140323
# dtype: float64

# %%
scaler = MinMaxScaler()

X_scaled = pd.DataFrame(scaler.fit_transform(X), columns=X.columns)

# %%
X
# Out:
#         floor_area_sqm  pri_sch_name_low  max_floor_lvl  flat_model_low  \
# 0                 90.0                 0             25               1
# 1                130.0                 0              9               1
# 2                144.0                 1             16               0
# 3                103.0                 0             11               1
# 4                 83.0                 1              4               1
# ...                ...               ...            ...             ...
# 150629           161.0                 1             12               0
# 150630           110.0                 1             16               1
# 150631           144.0                 1             15               0
# 150632            59.0                 0             10               1
# 150633           164.0                 1             12               0
#
#         sec_sch_name_low  hdb_age  hawker_within_2km  mrt_nearest_distance  \
# 0                      1       15               13.0            330.083069
# 1                      0       34                7.0            903.659703
# 2                      0       24                1.0           1334.251197
# 3                      0       29                9.0            907.453484
# 4                      1       34                1.0            412.343032
# ...                  ...      ...                ...                   ...
# 150629                 1       26                3.0            713.675852
# 150630                 1       20                1.0            239.773531
# 150631                 0       28                4.0            669.284215
# 150632                 0       47                8.0            502.030710
# 150633                 1       34                2.0            852.790099
#
#         flat_model_mid  mrt_name  ...  year_floor  maxfloor_secsch  year_age  \
# 0                    0         3  ...       22176        10.256460     30240
# 1                    0         4  ...       16096         8.301782     68408
# 2                    1         1  ...       28182         7.965960     48312
# 3                    0         4  ...        6036         8.362799     58348
# 4                    0         1  ...        4034         7.129379     68578
# ...                ...       ...  ...         ...              ...       ...
# 150629               1         2  ...       10100         7.731351     52520
# 150630               0         1  ...       10085         9.193265     40340
# 150631               1         2  ...       22220         9.030418     56560
# 150632               0         3  ...       16128         9.026882     94752
# 150633               1         1  ...       16144         8.799227     68612
#
#         age_execsold   age_pri_sch  floor_hawker  floor_mall1km  storey_range  \
# 0           0.000000  17079.501324     25.690465       0.000000             3
# 1           0.000000  14130.650141     24.819347       2.828427             2
# 2          37.947332  11972.376930     36.469165       0.000000             3
# 3           0.000000  11295.950305     16.062378       1.732051             1
# 4           0.000000  13640.819864      0.000000       1.414214             1
# ...              ...           ...           ...            ...           ...
# 150629     32.249031  10893.583083      0.000000       4.472136             1
# 150630      0.000000   2725.961605     21.679483       2.236068             1
# 150631     39.597980  14353.550790     28.722813       0.000000             3
# 150632      0.000000  37000.794964     22.449944       4.898979             2
# 150633      0.000000   7227.311710      0.000000       2.828427             2
#
#         which_floor  floor_maxfloor
# 0          3.496508        6.715383
# 1          2.772589        4.969813
# 2          3.737670        6.510258
# 3          1.098612        3.496508
# 4          0.693147        2.079442
# ...             ...             ...
# 150629     1.609438        4.094345
# 150630     1.609438        4.382027
# 150631     3.496508        6.204558
# 150632     2.772589        5.075174
# 150633     2.772589        5.257495
#
# [150634 rows x 29 columns]

# %% [markdown]
# ---------------------

# %% [markdown]
# ### Train-Test Split and checking Model Score

# %%
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, random_state=5)

# %%
#no skew no scale
lr = LinearRegression()
lr.fit(X_train, y_train)
print(lr.intercept_)
print(lr.coef_)
print('Linear Regression score:',lr.score(X_train,y_train))
lrpred=lr.predict(X_test)
print('Mean Squared Error: ',mean_squared_error(y_test,lrpred))
print('Mean Absolute Error: ',mean_absolute_error(y_test,lrpred))
print('Root Mean Squared Error: ',np.sqrt(mean_squared_error(y_test,lrpred)))
print('Test Score: ',lr.score(X_test, y_test))
# Out:
# 446550.6097619054
# [ 5.91522144e+05 -1.64420646e+04 -9.72603306e+04 -5.18695524e+04
#  -1.77024087e+04  2.67948025e+07  7.70155988e+04 -1.43786697e+05
#   2.78980933e+04  6.66454501e+04 -2.17006929e+07 -3.32146332e+04
#  -3.08548774e+04 -7.31945426e+04  5.17194670e+05 -3.04048455e+04
#  -4.45320323e+04  1.38361578e+05 -3.16956743e+03  2.17522237e+07
#   3.32929122e+04 -2.69937962e+07 -4.85152756e+04  3.64216088e+04
#   8.81232519e+04  5.85049536e+04 -3.38672525e+03  3.83946298e+05
#  -5.98067312e+05]
# Linear Regression score: 0.8628645748861994
# Mean Squared Error:  2774914756.5746236
# Mean Absolute Error:  39873.02334651694
# Root Mean Squared Error:  52677.45966326227
# Test Score:  0.8648744345532383

# %%
set(zip(X.columns, lr.coef_))
# Out:
# {('age_3room', -44532.03233368664),
#  ('age_execsold', -48515.27555637159),
#  ('age_pri_sch', 36421.60877168352),
#  ('age_totalunit', -3169.5674340966925),
#  ('flat_model_low', -51869.55241269164),
#  ('flat_model_mid', 27898.093328605057),
#  ('floor_area_sqm', 591522.1437856737),
#  ('floor_hawker', 88123.25187700614),
#  ('floor_hawker2km', 138361.5776784639),
#  ('floor_mall1km', 58504.9536261038),
#  ('floor_maxfloor', -598067.312393124),
#  ('hawker_within_2km', 77015.5988086328),
#  ('hdb_age', 26794802.508557264),
#  ('mall_within_2km', -73194.5425978183),
#  ('max_floor_5room', -30404.845470481017),
#  ('max_floor_lvl', -97260.3305516736),
#  ('maxfloor_secsch', 33292.91221356814),
#  ('mid', -21700692.928847115),
#  ('mrt_name', 66645.45009797753),
#  ('mrt_nearest_distance', -143786.6972124726),
#  ('planning_area_low', -33214.6332404103),
#  ('pri_sch_name_low', -16442.064574958087),
#  ('sec_sch_name_low', -17702.40873761863),
#  ('sec_sch_nearest_dist', -30854.87742532236),
#  ('sqm_year_max_floor', 517194.6699600143),
#  ('storey_range', -3386.7252538796065),
#  ('which_floor', 383946.2978471598),
#  ('year_age', -26993796.159167733),
#  ('year_floor', 21752223.743327547)}

# %%
print("R2 Score:", r2_score(y_test, lrpred))
print("Train Score:", lr.score(X_train, y_train))
print("Test Score:", lr.score(X_test, y_test))
print("Cross Validation Score:", cross_val_score(lr, X_train, y_train, cv=5).mean())
# Out:
# R2 Score: 0.8648744345532383
# Train Score: 0.8628645748861994
# Test Score: 0.8648744345532383
# Cross Validation Score: 0.8627778678271844

# %%
ridgeRegressor = Ridge()
ridgeRegressor.fit(X_train, y_train)
ridge_pred = ridgeRegressor.predict(X_test)

# Calculate model performance
# To derive other metrics, check out https://scikit-learn.org/stable/modules/classes.html#module-sklearn.metrics
R_squared = r2_score(ridge_pred, y_test)
print('Test R-squared score :', R_squared)
# Out:
# Test R-squared score : 0.8241722923586812

# %%
lassoRegressor = Lasso()
lassoRegressor.fit(X_train, y_train)
lasso_pred = lassoRegressor.predict(X_test)

# Calculate model performance
# To derive other metrics, check out https://scikit-learn.org/stable/modules/classes.html#module-sklearn.metrics
R_squared = r2_score(lasso_pred, y_test)
print('Test R-squared score :', R_squared)
# Out:
# Test R-squared score : 0.8234534177035755

# %%
# Get the y-intercept and the coefficients
intercept = ridgeRegressor.intercept_
coefficients = ridgeRegressor.coef_

# Create a string for the formula
formula = f"y = {intercept}"
for i, coef in enumerate(coefficients):
    formula += f" + {coef}*x{i+1}"

print(formula)
# Out:
# y = 455134.89749940764 + 581323.0761361134*x1 + -16310.545561693645*x2 + -98320.51512266556*x3 + -55656.349245031495*x4 + -17398.1935748816*x5 + 659905.8659502546*x6 + 76404.89440963924*x7 + -143330.2067692534*x8 + 25276.607727428833*x9 + 66190.0837144514*x10 + 142683.6740591073*x11 + -33149.808184297755*x12 + -22176.98408879016*x13 + -74063.18826843853*x14 + 507894.3612694026*x15 + -29519.954878456447*x16 + -42032.124977533174*x17 + 137833.87886235752*x18 + -7973.236758641711*x19 + -130187.957690276*x20 + 26053.34192473346*x21 + -810011.7483363939*x22 + -48899.022060569914*x23 + 36069.92037054003*x24 + 85797.73455149526*x25 + 56010.1927809599*x26 + -408.96467004855003*x27 + 353340.3157107655*x28 + -559953.9314839307*x29

# %% [markdown]
# -----------------------------

# %% [markdown]
# ## Saving the Model to a Pickle File for Streamlit

# %%
# Assuming 'data' is your DataFrame
feature_names = data.columns.tolist()

# Print the feature names
print(feature_names)
# Out:
# ['flat_type', 'storey_range', 'floor_area_sqm', 'flat_model', 'resale_price', 'tranc_year', 'tranc_month', 'lower', 'upper', 'mid', 'hdb_age', 'max_floor_lvl', 'commercial', 'market_hawker', 'multistorey_carpark', 'total_dwelling_units', '1room_sold', '2room_sold', '3room_sold', '4room_sold', '5room_sold', 'exec_sold', 'multigen_sold', 'studio_apartment_sold', '1room_rental', '2room_rental', '3room_rental', 'other_room_rental', 'planning_area', 'mall_nearest_distance', 'mall_within_500m', 'mall_within_1km', 'mall_within_2km', 'hawker_nearest_distance', 'hawker_within_500m', 'hawker_within_1km', 'hawker_within_2km', 'hawker_food_stalls', 'hawker_market_stalls', 'mrt_nearest_distance', 'mrt_name', 'mrt_interchange', 'bus_stop_nearest_distance', 'pri_sch_nearest_distance', 'pri_sch_name', 'vacancy', 'pri_sch_affiliation', 'sec_sch_nearest_dist', 'sec_sch_name', 'cutoff_point']

# %%
import pickle

# Save the model to a file
with open('ridge_model.pkl', 'wb') as f:
    pickle.dump(ridgeRegressor, f)

# Save the scaler to a file
with open('scaler.pkl', 'wb') as f:
    pickle.dump(scaler, f)

# %%
# Assuming 'encoded_data' is your DataFrame
feature_names = encoded_data.columns.tolist()

# Print the feature names
print(feature_names)
# Out:
# ['storey_range', 'floor_area_sqm', 'resale_price', 'tranc_year', 'tranc_month', 'lower', 'upper', 'mid', 'hdb_age', 'max_floor_lvl', 'total_dwelling_units', '2room_sold', '3room_sold', '4room_sold', '5room_sold', 'exec_sold', 'multigen_sold', 'studio_apartment_sold', '1room_rental', '2room_rental', '3room_rental', 'other_room_rental', 'mall_nearest_distance', 'mall_within_500m', 'mall_within_1km', 'mall_within_2km', 'hawker_nearest_distance', 'hawker_within_500m', 'hawker_within_1km', 'hawker_within_2km', 'hawker_food_stalls', 'hawker_market_stalls', 'mrt_nearest_distance', 'mrt_name', 'bus_stop_nearest_distance', 'pri_sch_nearest_distance', 'vacancy', 'sec_sch_nearest_dist', 'cutoff_point', '1room_sold_255', 'mrt_interchange_1', 'pri_sch_affiliation_1', 'planning_area_low', 'planning_area_mid1', 'planning_area_mid2', 'flat_model_low', 'flat_model_mid', 'flat_type_low', 'flat_type_mid', 'multistorey_carpark_Y', 'commercial_Y', 'market_hawker_Y', 'pri_sch_name_low', 'pri_sch_name_mid1', 'pri_sch_name_mid2', 'sec_sch_name_low', 'sec_sch_name_mid1', 'sec_sch_name_mid2', 'sqm_year_max_floor', 'max_floor_5room', 'age_3room', 'floor_hawker2km', 'age_totalunit', 'year_floor', 'maxfloor_secsch', 'year_age', 'age_execsold', 'age_pri_sch', 'floor_hawker', 'floor_mall1km', 'which_floor', 'floor_maxfloor']
